# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
from statsmodels.stats import diagnostic
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from stargazer.stargazer import Stargazer
from statsmodels.stats.outliers_influence import variance_inflation_factor
sns.set_theme(style="white")

# %% [markdown]
# # Extension 1. Results of Table 3 and 4 for 2019

# %% [markdown]
# ## World Values Survey

# %%
df_wv = pd.read_csv(
    'WVS_Cross-National_Wave_7_csv_v5_0.csv')
df_wv.columns
# Out:
# Index(['version', 'doi', 'A_WAVE', 'A_YEAR', 'A_STUDY', 'B_COUNTRY',
#        'B_COUNTRY_ALPHA', 'C_COW_NUM', 'C_COW_ALPHA', 'D_INTERVIEW',
#        ...
#        'WVS_Polmistrust_PartyVoter', 'WVS_LR_MedianVoter',
#        'WVS_LibCon_MedianVoter', 'v2psbars', 'v2psorgs', 'v2psprbrch',
#        'v2psprlnks', 'v2psplats', 'v2xnp_client', 'v2xps_party'],
#       dtype='object', length=606)

# %%
unem_columns = [column for column in df_wv.columns if 'unem' in column]
unem_columns
# Out:
# ['unemployfem', 'unemploymale', 'unemploytotal']

# %%
unem_columns.append('B_COUNTRY_ALPHA')

# %%
df_wv[unem_columns][df_wv['B_COUNTRY_ALPHA']=='AUS'].value_counts()
# Out:
# unemployfem  unemploymale  unemploytotal  B_COUNTRY_ALPHA
# 5.33         5.22          5.27           AUS                1813
# dtype: int64

# %% [markdown]
# ## Paper

# %%
df_cross_country = pd.read_stata('crosscountry_dataset.dta')
df_cross_country
# Out:
#     isocode  flfp2000  female_ownership  women_politics      plow  \
# 0       ABW       NaN               NaN             NaN  0.000000
# 1       AFG      31.3               2.8             NaN  0.999969
# 2       AGO      75.2              56.6            16.0  0.000000
# 3       AIA       NaN               NaN             NaN  0.000000
# 4       ALB      50.2              10.8             5.0  1.000000
# ..      ...       ...               ...             ...       ...
# 229     YUG       NaN              28.8             NaN  1.000000
# 230     ZAF      44.3              22.6            30.0  0.540551
# 231     ZAR      55.5              38.9             NaN  0.000000
# 232     ZMB      62.1              37.2            10.0  0.000000
# 233     ZWE      64.0              56.2            14.0  0.000002
#
#      agricultural_suitability  tropical_climate  large_animals  \
# 0                    0.829847          1.000000       1.000000
# 1                    0.229267          0.785295       1.000000
# 2                    0.921061          1.000000       0.998896
# 3                    0.829847          1.000000       1.000000
# 4                    0.555928          0.359318       1.000000
# ..                        ...               ...            ...
# 229                  0.775941          0.080989       1.000000
# 230                  0.865508          0.901535       0.999999
# 231                  0.423659          1.000000       0.928739
# 232                  0.955900          1.000000       0.754301
# 233                  0.913061          1.000000       0.994593
#
#      political_hierarchies  economic_complexity  ...  terrslope2     soil2  \
# 0                 4.000000             7.000000  ...   23.248068  0.796877
# 1                 3.633688             6.199330  ...  623.563904  0.068421
# 2                 2.720727             6.697217  ...  358.600311  0.970410
# 3                 4.000000             7.000000  ...   23.248068  0.796877
# 4                 3.029723             5.035051  ...  986.303772  0.609834
# ..                     ...                  ...  ...         ...       ...
# 229               3.822862             7.444995  ...  567.683655  0.759602
# 230               3.550035             5.920460  ...  594.206116  0.745225
# 231               2.383938             6.545618  ...  104.809097  0.970129
# 232               2.390349             5.871349  ...  139.062561  0.892828
# 233               3.104864             6.337659  ...  365.561829  0.890949
#
#       avg_temp2   avg_precip2  slope_soil  slope_temp  slope_precip  \
# 0    694.377380   9291.514648    4.304165  127.054840    464.768494
# 1     74.482773    538.041870    6.531851  215.510483    579.226624
# 2    418.034027   9126.774414   18.654472  387.178406   1809.105957
# 3    694.377380   9291.514648    4.304165  127.054840    464.768494
# 4    122.236977   6294.060547   24.525124  347.221527   2491.556885
# ..          ...           ...         ...         ...           ...
# 229  116.812553   4452.978027   20.765686  257.512268   1589.931641
# 230  312.183350   4103.467285   21.043222  430.698578   1561.507446
# 231  546.375610  15426.306641   10.083570  239.301346   1271.541260
# 232  442.156647   7636.923828   11.142666  247.966599   1030.538818
# 233  406.286194   2897.081787   18.047073  385.386444   1029.107666
#
#      soil_temp  soil_precip  temp_precip
# 0    23.523033    86.047607  2540.042725
# 1     2.257479     6.067417   200.187042
# 2    20.141113    94.110115  1953.279907
# 3    23.523033    86.047607  2540.042725
# 4     8.633903    61.954281   877.135620
# ..         ...          ...          ...
# 229   9.419717    58.159191   721.223755
# 230  15.252764    55.299240  1131.827759
# 231  23.022926   122.333626  2903.197754
# 232  19.868818    82.573975  1837.584473
# 233  19.025778    50.805035  1084.916748
#
# [234 rows x 57 columns]

# %%
df_cross_country[df_cross_country['isocode'] == 'USA']
# Out:
#     isocode  flfp2000  female_ownership  women_politics      plow  \
# 217     USA      59.5               NaN            13.0  0.972528
#
#      agricultural_suitability  tropical_climate  large_animals  \
# 217                  0.855395          0.043982       0.994987
#
#      political_hierarchies  economic_complexity  ...  terrslope2     soil2  \
# 217               3.949898             7.927381  ...  270.071136  0.944029
#
#      avg_temp2  avg_precip2  slope_soil  slope_temp  slope_precip  soil_temp  \
# 217   75.51651  7971.624512   15.967307  142.810471    1467.27832   8.443326
#
#      soil_precip  temp_precip
# 217    86.749306     775.8797
#
# [1 rows x 57 columns]

# %% [markdown]
# ## World Bank (for all indicators)

# %%
df_wb = pd.read_csv('data_table3.csv').set_index(['Country Name', 'Country Code'])

# %%
df_wb
# Out:
#                                                                                                      Series Name  \
# Country Name                                     Country Code
# Afghanistan                                      AFG           Labor force participation rate, female (% of f...
#                                                  AFG           Firms with female participation in ownership (...
#                                                  AFG           Proportion of seats held by women in national ...
# Albania                                          ALB           Labor force participation rate, female (% of f...
#                                                  ALB           Firms with female participation in ownership (...
# ...                                                                                                          ...
# NaN                                              NaN                                                         NaN
#                                                  NaN                                                         NaN
#                                                  NaN                                                         NaN
# Data from database: World Development Indicators NaN                                                         NaN
# Last Updated: 12/22/2022                         NaN                                                         NaN
#
#                                                                      Series Code  \
# Country Name                                     Country Code
# Afghanistan                                      AFG           SL.TLF.ACTI.FE.ZS
#                                                  AFG              IC.FRM.FEMO.ZS
#                                                  AFG              SG.GEN.PARL.ZS
# Albania                                          ALB           SL.TLF.ACTI.FE.ZS
#                                                  ALB              IC.FRM.FEMO.ZS
# ...                                                                          ...
# NaN                                              NaN                         NaN
#                                                  NaN                         NaN
#                                                  NaN                         NaN
# Data from database: World Development Indicators NaN                         NaN
# Last Updated: 12/22/2022                         NaN                         NaN
#
#                                                               1999 [YR1999]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                   15.4
#                                                  AFG                     ..
#                                                  AFG                     ..
# Albania                                          ALB                  58.87
#                                                  ALB                     ..
# ...                                                                     ...
# NaN                                              NaN                    NaN
#                                                  NaN                    NaN
#                                                  NaN                    NaN
# Data from database: World Development Indicators NaN                    NaN
# Last Updated: 12/22/2022                         NaN                    NaN
#
#                                                               2000 [YR2000]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                  15.35
#                                                  AFG                     ..
#                                                  AFG                     ..
# Albania                                          ALB                  57.89
#                                                  ALB                     ..
# ...                                                                     ...
# NaN                                              NaN                    NaN
#                                                  NaN                    NaN
#                                                  NaN                    NaN
# Data from database: World Development Indicators NaN                    NaN
# Last Updated: 12/22/2022                         NaN                    NaN
#
#                                                               2001 [YR2001]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                   15.5
#                                                  AFG                     ..
#                                                  AFG                     ..
# Albania                                          ALB                  56.71
#                                                  ALB                     ..
# ...                                                                     ...
# NaN                                              NaN                    NaN
#                                                  NaN                    NaN
#                                                  NaN                    NaN
# Data from database: World Development Indicators NaN                    NaN
# Last Updated: 12/22/2022                         NaN                    NaN
#
#                                                               2002 [YR2002]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                   15.7
#                                                  AFG                     ..
#                                                  AFG                     ..
# Albania                                          ALB                  56.06
#                                                  ALB                     ..
# ...                                                                     ...
# NaN                                              NaN                    NaN
#                                                  NaN                    NaN
#                                                  NaN                    NaN
# Data from database: World Development Indicators NaN                    NaN
# Last Updated: 12/22/2022                         NaN                    NaN
#
#                                                               2003 [YR2003]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                  15.92
#                                                  AFG                     ..
#                                                  AFG                     ..
# Albania                                          ALB                   55.3
#                                                  ALB                     ..
# ...                                                                     ...
# NaN                                              NaN                    NaN
#                                                  NaN                    NaN
#                                                  NaN                    NaN
# Data from database: World Development Indicators NaN                    NaN
# Last Updated: 12/22/2022                         NaN                    NaN
#
#                                                               2004 [YR2004]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                  16.13
#                                                  AFG                     ..
#                                                  AFG                     ..
# Albania                                          ALB                  54.57
#                                                  ALB                     ..
# ...                                                                     ...
# NaN                                              NaN                    NaN
#                                                  NaN                    NaN
#                                                  NaN                    NaN
# Data from database: World Development Indicators NaN                    NaN
# Last Updated: 12/22/2022                         NaN                    NaN
#
#                                                                   2005 [YR2005]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                      16.33
#                                                  AFG                         ..
#                                                  AFG           27.3092369477912
# Albania                                          ALB                      53.88
#                                                  ALB                       12.8
# ...                                                                         ...
# NaN                                              NaN                        NaN
#                                                  NaN                        NaN
#                                                  NaN                        NaN
# Data from database: World Development Indicators NaN                        NaN
# Last Updated: 12/22/2022                         NaN                        NaN
#
#                                                                   2006 [YR2006]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                      16.12
#                                                  AFG                         ..
#                                                  AFG           27.3092369477912
# Albania                                          ALB                      53.43
#                                                  ALB                         ..
# ...                                                                         ...
# NaN                                              NaN                        NaN
#                                                  NaN                        NaN
#                                                  NaN                        NaN
# Data from database: World Development Indicators NaN                        NaN
# Last Updated: 12/22/2022                         NaN                        NaN
#
#                                                                ...  \
# Country Name                                     Country Code  ...
# Afghanistan                                      AFG           ...
#                                                  AFG           ...
#                                                  AFG           ...
# Albania                                          ALB           ...
#                                                  ALB           ...
# ...                                                            ...
# NaN                                              NaN           ...
#                                                  NaN           ...
#                                                  NaN           ...
# Data from database: World Development Indicators NaN           ...
# Last Updated: 12/22/2022                         NaN           ...
#
#                                                                  2012 [YR2012]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                     16.44
#                                                  AFG                        ..
#                                                  AFG           27.710843373494
# Albania                                          ALB                      55.1
#                                                  ALB                        ..
# ...                                                                        ...
# NaN                                              NaN                       NaN
#                                                  NaN                       NaN
#                                                  NaN                       NaN
# Data from database: World Development Indicators NaN                       NaN
# Last Updated: 12/22/2022                         NaN                       NaN
#
#                                                                  2013 [YR2013]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                     17.42
#                                                  AFG                        ..
#                                                  AFG           27.710843373494
# Albania                                          ALB                     50.58
#                                                  ALB                      13.1
# ...                                                                        ...
# NaN                                              NaN                       NaN
#                                                  NaN                       NaN
#                                                  NaN                       NaN
# Data from database: World Development Indicators NaN                       NaN
# Last Updated: 12/22/2022                         NaN                       NaN
#
#                                                                  2014 [YR2014]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                     18.46
#                                                  AFG                       2.2
#                                                  AFG           27.710843373494
# Albania                                          ALB                     50.18
#                                                  ALB                        ..
# ...                                                                        ...
# NaN                                              NaN                       NaN
#                                                  NaN                       NaN
#                                                  NaN                       NaN
# Data from database: World Development Indicators NaN                       NaN
# Last Updated: 12/22/2022                         NaN                       NaN
#
#                                                                  2015 [YR2015]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                     19.55
#                                                  AFG                        ..
#                                                  AFG           27.710843373494
# Albania                                          ALB                     54.05
#                                                  ALB                        ..
# ...                                                                        ...
# NaN                                              NaN                       NaN
#                                                  NaN                       NaN
#                                                  NaN                       NaN
# Data from database: World Development Indicators NaN                       NaN
# Last Updated: 12/22/2022                         NaN                       NaN
#
#                                                                  2016 [YR2016]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                      20.7
#                                                  AFG                        ..
#                                                  AFG           27.710843373494
# Albania                                          ALB                      56.4
#                                                  ALB                        ..
# ...                                                                        ...
# NaN                                              NaN                       NaN
#                                                  NaN                       NaN
#                                                  NaN                       NaN
# Data from database: World Development Indicators NaN                       NaN
# Last Updated: 12/22/2022                         NaN                       NaN
#
#                                                                  2017 [YR2017]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                     21.91
#                                                  AFG                        ..
#                                                  AFG           27.710843373494
# Albania                                          ALB                     55.54
#                                                  ALB                        ..
# ...                                                                        ...
# NaN                                              NaN                       NaN
#                                                  NaN                       NaN
#                                                  NaN                       NaN
# Data from database: World Development Indicators NaN                       NaN
# Last Updated: 12/22/2022                         NaN                       NaN
#
#                                                               2018 [YR2018]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                  22.32
#                                                  AFG                     ..
#                                                  AFG                     ..
# Albania                                          ALB                  59.12
#                                                  ALB                     ..
# ...                                                                     ...
# NaN                                              NaN                    NaN
#                                                  NaN                    NaN
#                                                  NaN                    NaN
# Data from database: World Development Indicators NaN                    NaN
# Last Updated: 12/22/2022                         NaN                    NaN
#
#                                                                   2019 [YR2019]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                      22.74
#                                                  AFG                         ..
#                                                  AFG           27.8688524590164
# Albania                                          ALB                      61.46
#                                                  ALB                       20.7
# ...                                                                         ...
# NaN                                              NaN                        NaN
#                                                  NaN                        NaN
#                                                  NaN                        NaN
# Data from database: World Development Indicators NaN                        NaN
# Last Updated: 12/22/2022                         NaN                        NaN
#
#                                                                   2020 [YR2020]  \
# Country Name                                     Country Code
# Afghanistan                                      AFG                         ..
#                                                  AFG                         ..
#                                                  AFG           27.0161290322581
# Albania                                          ALB                         ..
#                                                  ALB                         ..
# ...                                                                         ...
# NaN                                              NaN                        NaN
#                                                  NaN                        NaN
#                                                  NaN                        NaN
# Data from database: World Development Indicators NaN                        NaN
# Last Updated: 12/22/2022                         NaN                        NaN
#
#                                                                   2021 [YR2021]
# Country Name                                     Country Code
# Afghanistan                                      AFG                         ..
#                                                  AFG                         ..
#                                                  AFG           27.0161290322581
# Albania                                          ALB                         ..
#                                                  ALB                         ..
# ...                                                                         ...
# NaN                                              NaN                        NaN
#                                                  NaN                        NaN
#                                                  NaN                        NaN
# Data from database: World Development Indicators NaN                        NaN
# Last Updated: 12/22/2022                         NaN                        NaN
#
# [656 rows x 25 columns]

# %% [markdown]
# ### Female ownership 2010-2019, replace missing values with previous years

# %%
female_ownership2010_to_2019 = df_wb[df_wb['Series Name'] == 'Firms with female participation in ownership (% of firms)'][['2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]',
                                                                                                                     '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]']].reset_index()
female_ownership2010_to_2019.replace('..', np.nan, inplace=True)
female_ownership2010_to_2019.iloc[:, 2:].astype(float)
female_ownership2010_to_2019
# Out:
#               Country Name Country Code  2003 [YR2003] 2004 [YR2004]  \
# 0              Afghanistan          AFG            NaN           NaN
# 1                  Albania          ALB            NaN           NaN
# 2                  Algeria          DZA            NaN           NaN
# 3           American Samoa          ASM            NaN           NaN
# 4                  Andorra          AND            NaN           NaN
# ..                     ...          ...            ...           ...
# 212  Virgin Islands (U.S.)          VIR            NaN           NaN
# 213     West Bank and Gaza          PSE            NaN           NaN
# 214            Yemen, Rep.          YEM            NaN           NaN
# 215                 Zambia          ZMB            NaN           NaN
# 216               Zimbabwe          ZWE            NaN           NaN
#
#     2005 [YR2005] 2006 [YR2006] 2007 [YR2007] 2008 [YR2008] 2009 [YR2009]  \
# 0             NaN           NaN           NaN           2.8           NaN
# 1            12.8           NaN          10.8           NaN           NaN
# 2             NaN           NaN            15           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 212           NaN           NaN           NaN           NaN           NaN
# 213           NaN            18           NaN           NaN           NaN
# 214           NaN           NaN           NaN           NaN           NaN
# 215           NaN           NaN          37.2           NaN           NaN
# 216           NaN           NaN           NaN           NaN           NaN
#
#     2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# 0             NaN           NaN           NaN           NaN           2.2
# 1             NaN           NaN           NaN          13.1           NaN
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 212           NaN           NaN           NaN           NaN           NaN
# 213           NaN           NaN           NaN          10.7           NaN
# 214           6.4           NaN           NaN           6.6           NaN
# 215           NaN           NaN           NaN          43.7           NaN
# 216           NaN          56.2           NaN           NaN           NaN
#
#     2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019]
# 0             NaN           NaN           NaN           NaN           NaN
# 1             NaN           NaN           NaN           NaN          20.7
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 212           NaN           NaN           NaN           NaN           NaN
# 213           NaN           NaN           NaN           NaN             6
# 214           NaN           NaN           NaN           NaN           NaN
# 215           NaN           NaN           NaN           NaN          41.5
# 216           NaN          42.5           NaN           NaN           NaN
#
# [217 rows x 19 columns]

# %%
for col in range(-2, -11, -1):
    female_ownership2010_to_2019['2019 [YR2019]'] = female_ownership2010_to_2019['2019 [YR2019]'].fillna(
        female_ownership2010_to_2019.iloc[:, col])
    print('values not nan', female_ownership2010_to_2019['2019 [YR2019]'].notna(
    ).sum(), 'year 2019 -', female_ownership2010_to_2019.iloc[:, col].name)
# Out:
# values not nan 47 year 2019 - 2018 [YR2018]
# values not nan 58 year 2019 - 2017 [YR2017]
# values not nan 75 year 2019 - 2016 [YR2016]
# values not nan 83 year 2019 - 2015 [YR2015]
# values not nan 94 year 2019 - 2014 [YR2014]
# values not nan 107 year 2019 - 2013 [YR2013]
# values not nan 108 year 2019 - 2012 [YR2012]
# values not nan 111 year 2019 - 2011 [YR2011]
# values not nan 130 year 2019 - 2010 [YR2010]

# %%
female_ownership2010_to_2019 = female_ownership2010_to_2019[['Country Name', 'Country Code', '2019 [YR2019]']]
female_ownership2010_to_2019
# Out:
#               Country Name Country Code 2019 [YR2019]
# 0              Afghanistan          AFG           2.2
# 1                  Albania          ALB          20.7
# 2                  Algeria          DZA           NaN
# 3           American Samoa          ASM           NaN
# 4                  Andorra          AND           NaN
# ..                     ...          ...           ...
# 212  Virgin Islands (U.S.)          VIR           NaN
# 213     West Bank and Gaza          PSE             6
# 214            Yemen, Rep.          YEM           6.6
# 215                 Zambia          ZMB          41.5
# 216               Zimbabwe          ZWE          42.5
#
# [217 rows x 3 columns]

# %% [markdown]
# ### All indicators

# %%
flfp2019 = df_wb[df_wb['Series Name'] == 'Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)']['2019 [YR2019]'].reset_index()
women_politics2019 = df_wb[df_wb['Series Name'] == 'Proportion of seats held by women in national parliaments (%)']['2019 [YR2019]'].reset_index()

# %%
[[flfp2019,women_politics2019]]
# Out:
# [[              Country Name Country Code 2019 [YR2019]
#   0              Afghanistan          AFG         22.74
#   1                  Albania          ALB         61.46
#   2                  Algeria          DZA          18.7
#   3           American Samoa          ASM            ..
#   4                  Andorra          AND            ..
#   ..                     ...          ...           ...
#   212  Virgin Islands (U.S.)          VIR         67.36
#   213     West Bank and Gaza          PSE         19.15
#   214            Yemen, Rep.          YEM          6.29
#   215                 Zambia          ZMB         71.29
#   216               Zimbabwe          ZWE         79.11
#
#   [217 rows x 3 columns],
#                 Country Name Country Code      2019 [YR2019]
#   0              Afghanistan          AFG   27.8688524590164
#   1                  Albania          ALB   29.5081967213115
#   2                  Algeria          DZA   25.7575757575758
#   3           American Samoa          ASM                 ..
#   4                  Andorra          AND   46.4285714285714
#   ..                     ...          ...                ...
#   212  Virgin Islands (U.S.)          VIR                 ..
#   213     West Bank and Gaza          PSE                 ..
#   214            Yemen, Rep.          YEM  0.332225913621262
#   215                 Zambia          ZMB   17.9640718562874
#   216               Zimbabwe          ZWE   31.8518518518519
#
#   [217 rows x 3 columns]]]

# %% [markdown]
# ## Paper + WorldBank datasets for 2019

# %%
df_cross_country2019 = pd.merge(
    df_cross_country, flfp2019, left_on='isocode', right_on='Country Code', how='left'
).drop(['Country Code', 'Country Name'], axis=1
       ).rename(columns={'2019 [YR2019]': 'flfp2019'}
                ).merge(women_politics2019, left_on='isocode', right_on='Country Code', how='left'
                        ).drop(['Country Code', 'Country Name'], axis=1
                               ).rename(columns={'2019 [YR2019]': 'women_politics2019'}
                                        ).merge(female_ownership2010_to_2019, left_on='isocode', right_on='Country Code', how='left'
                                                ).drop(['Country Code', 'Country Name'], axis=1
                                                       ).rename(columns={'2019 [YR2019]': 'female_ownership2010_to_2019'})

# %%
df_cross_country2019[['flfp2019', 'women_politics2019', 'female_ownership2010_to_2019']] = df_cross_country2019[['flfp2019', 'women_politics2019', 'female_ownership2010_to_2019']
                                                                                                        ].replace('..', np.nan).astype(float)

# %%
df_cross_country2019
# Out:
#     isocode  flfp2000  female_ownership  women_politics      plow  \
# 0       ABW       NaN               NaN             NaN  0.000000
# 1       AFG      31.3               2.8             NaN  0.999969
# 2       AGO      75.2              56.6            16.0  0.000000
# 3       AIA       NaN               NaN             NaN  0.000000
# 4       ALB      50.2              10.8             5.0  1.000000
# ..      ...       ...               ...             ...       ...
# 229     YUG       NaN              28.8             NaN  1.000000
# 230     ZAF      44.3              22.6            30.0  0.540551
# 231     ZAR      55.5              38.9             NaN  0.000000
# 232     ZMB      62.1              37.2            10.0  0.000000
# 233     ZWE      64.0              56.2            14.0  0.000002
#
#      agricultural_suitability  tropical_climate  large_animals  \
# 0                    0.829847          1.000000       1.000000
# 1                    0.229267          0.785295       1.000000
# 2                    0.921061          1.000000       0.998896
# 3                    0.829847          1.000000       1.000000
# 4                    0.555928          0.359318       1.000000
# ..                        ...               ...            ...
# 229                  0.775941          0.080989       1.000000
# 230                  0.865508          0.901535       0.999999
# 231                  0.423659          1.000000       0.928739
# 232                  0.955900          1.000000       0.754301
# 233                  0.913061          1.000000       0.994593
#
#      political_hierarchies  economic_complexity  ...   avg_precip2  \
# 0                 4.000000             7.000000  ...   9291.514648
# 1                 3.633688             6.199330  ...    538.041870
# 2                 2.720727             6.697217  ...   9126.774414
# 3                 4.000000             7.000000  ...   9291.514648
# 4                 3.029723             5.035051  ...   6294.060547
# ..                     ...                  ...  ...           ...
# 229               3.822862             7.444995  ...   4452.978027
# 230               3.550035             5.920460  ...   4103.467285
# 231               2.383938             6.545618  ...  15426.306641
# 232               2.390349             5.871349  ...   7636.923828
# 233               3.104864             6.337659  ...   2897.081787
#
#      slope_soil  slope_temp  slope_precip  soil_temp  soil_precip  \
# 0      4.304165  127.054840    464.768494  23.523033    86.047607
# 1      6.531851  215.510483    579.226624   2.257479     6.067417
# 2     18.654472  387.178406   1809.105957  20.141113    94.110115
# 3      4.304165  127.054840    464.768494  23.523033    86.047607
# 4     24.525124  347.221527   2491.556885   8.633903    61.954281
# ..          ...         ...           ...        ...          ...
# 229   20.765686  257.512268   1589.931641   9.419717    58.159191
# 230   21.043222  430.698578   1561.507446  15.252764    55.299240
# 231   10.083570  239.301346   1271.541260  23.022926   122.333626
# 232   11.142666  247.966599   1030.538818  19.868818    82.573975
# 233   18.047073  385.386444   1029.107666  19.025778    50.805035
#
#      temp_precip  flfp2019  women_politics2019  female_ownership2010_to_2019
# 0    2540.042725       NaN                 NaN                           NaN
# 1     200.187042     22.74           27.868852                           2.2
# 2    1953.279907     76.88           30.000000                          56.6
# 3    2540.042725       NaN                 NaN                           NaN
# 4     877.135620     61.46           29.508197                          20.7
# ..           ...       ...                 ...                           ...
# 229   721.223755       NaN                 NaN                           NaN
# 230  1131.827759     54.07           46.347607                           NaN
# 231  2903.197754       NaN                 NaN                           NaN
# 232  1837.584473     71.29           17.964072                          41.5
# 233  1084.916748     79.11           31.851852                          42.5
#
# [234 rows x 60 columns]

# %% [markdown]
# ## AES

# %%
# compute the average effect size for the outcome columns flfp2000, female_ownership and women_politics
# for each country in the cross-country dataset
df_cross_country['aes'] = pd.concat([df_cross_country['flfp2000'] /
                                     df_cross_country[df_cross_country.plow == 0]['flfp2000'].std(
),
    df_cross_country['female_ownership'] /
    df_cross_country[df_cross_country.plow == 0]['female_ownership'].std(
),
    df_cross_country['women_politics'] /
    df_cross_country[df_cross_country.plow == 0]['women_politics'].std()
],
    axis=1).dropna(how='any').mean(axis=1)  # dropped rows with any missing values, to match the stata code
# Still coudln't match the standard errors (they might be calculated with a different regression
# on other data


df_cross_country2019['aes2019'] = pd.concat([df_cross_country2019['flfp2019'] /
                                         df_cross_country2019[df_cross_country2019.plow == 0]['flfp2019'].std(
),
    df_cross_country2019['female_ownership2010_to_2019'] /
    df_cross_country2019[df_cross_country2019.plow == 0]['female_ownership2010_to_2019'].std(
),
    df_cross_country2019['women_politics2019'] /
    df_cross_country2019[df_cross_country2019.plow ==
                         0]['women_politics2019'].std()
],
    axis=1).dropna(how='any').mean(axis=1)

# %% [markdown]
# # Extension 2: New outcome variable. Plow vs Unpaid female labour.
#
# **Indicator**
#
# Proportion of time spent on unpaid domestic and care work, female (% of 24 hour day)

# %%
df_f_unpaid = pd.read_excel('female_unpaid_work.xls').drop(['Indicator Name', 'Indicator Code'], axis=1).iloc[:,:-2]
df_f_unpaid
# Out:
#                     Country Name Country Code  1960  1961  1962  1963  1964  \
# 0                          Aruba          ABW   NaN   NaN   NaN   NaN   NaN
# 1    Africa Eastern and Southern          AFE   NaN   NaN   NaN   NaN   NaN
# 2                    Afghanistan          AFG   NaN   NaN   NaN   NaN   NaN
# 3     Africa Western and Central          AFW   NaN   NaN   NaN   NaN   NaN
# 4                         Angola          AGO   NaN   NaN   NaN   NaN   NaN
# ..                           ...          ...   ...   ...   ...   ...   ...
# 261                       Kosovo          XKX   NaN   NaN   NaN   NaN   NaN
# 262                  Yemen, Rep.          YEM   NaN   NaN   NaN   NaN   NaN
# 263                 South Africa          ZAF   NaN   NaN   NaN   NaN   NaN
# 264                       Zambia          ZMB   NaN   NaN   NaN   NaN   NaN
# 265                     Zimbabwe          ZWE   NaN   NaN   NaN   NaN   NaN
#
#      1965  1966  1967  ...      2010  2011  2012  2013  2014  2015  2016  \
# 0     NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...   ...   ...  ...       ...   ...   ...   ...   ...   ...   ...
# 261   NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262   NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 263   NaN   NaN   NaN  ...  15.55556   NaN   NaN   NaN   NaN   NaN   NaN
# 264   NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 265   NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      2017  2018  2019
# 0     NaN   NaN   NaN
# 1     NaN   NaN   NaN
# 2     NaN   NaN   NaN
# 3     NaN   NaN   NaN
# 4     NaN   NaN   NaN
# ..    ...   ...   ...
# 261   NaN   NaN   NaN
# 262   NaN   NaN   NaN
# 263   NaN   NaN   NaN
# 264   NaN   NaN   NaN
# 265   NaN   NaN   NaN
#
# [266 rows x 62 columns]

# %%
df_f_unpaid.iloc[:, 2:] = df_f_unpaid.iloc[:, 2:].astype(float)
df_f_unpaid
# Out:
#                     Country Name Country Code  1960  1961  1962  1963  1964  \
# 0                          Aruba          ABW   NaN   NaN   NaN   NaN   NaN
# 1    Africa Eastern and Southern          AFE   NaN   NaN   NaN   NaN   NaN
# 2                    Afghanistan          AFG   NaN   NaN   NaN   NaN   NaN
# 3     Africa Western and Central          AFW   NaN   NaN   NaN   NaN   NaN
# 4                         Angola          AGO   NaN   NaN   NaN   NaN   NaN
# ..                           ...          ...   ...   ...   ...   ...   ...
# 261                       Kosovo          XKX   NaN   NaN   NaN   NaN   NaN
# 262                  Yemen, Rep.          YEM   NaN   NaN   NaN   NaN   NaN
# 263                 South Africa          ZAF   NaN   NaN   NaN   NaN   NaN
# 264                       Zambia          ZMB   NaN   NaN   NaN   NaN   NaN
# 265                     Zimbabwe          ZWE   NaN   NaN   NaN   NaN   NaN
#
#      1965  1966  1967  ...      2010  2011  2012  2013  2014  2015  2016  \
# 0     NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...   ...   ...  ...       ...   ...   ...   ...   ...   ...   ...
# 261   NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262   NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 263   NaN   NaN   NaN  ...  15.55556   NaN   NaN   NaN   NaN   NaN   NaN
# 264   NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 265   NaN   NaN   NaN  ...       NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      2017  2018  2019
# 0     NaN   NaN   NaN
# 1     NaN   NaN   NaN
# 2     NaN   NaN   NaN
# 3     NaN   NaN   NaN
# 4     NaN   NaN   NaN
# ..    ...   ...   ...
# 261   NaN   NaN   NaN
# 262   NaN   NaN   NaN
# 263   NaN   NaN   NaN
# 264   NaN   NaN   NaN
# 265   NaN   NaN   NaN
#
# [266 rows x 62 columns]

# %%
# lots of no values at all for some countries (from the 1960s) values
df_f_unpaid.set_index(['Country Name','Country Code']).T.count().value_counts()
# Out:
# 0     177
# 1      44
# 2      29
# 3       6
# 4       6
# 5       2
# 6       1
# 17      1
# dtype: int64

# %%
for col in range(-2, -21, -1):
    df_f_unpaid['2019'] = df_f_unpaid['2019'].fillna(
        df_f_unpaid.iloc[:, col])
    print('values not nan', df_f_unpaid['2019'].notna(
    ).sum(), 'year 2019 -', df_f_unpaid.iloc[:, col].name)

df_f_unpaid2000_to_2019 = df_f_unpaid[['Country Name', 'Country Code', '2019']]
df_f_unpaid2000_to_2019
# Out:
# values not nan 7 year 2019 - 2018
# values not nan 13 year 2019 - 2017
# values not nan 20 year 2019 - 2016
# values not nan 31 year 2019 - 2015
# values not nan 37 year 2019 - 2014
# values not nan 46 year 2019 - 2013
# values not nan 52 year 2019 - 2012
# values not nan 56 year 2019 - 2011
# values not nan 66 year 2019 - 2010
# values not nan 71 year 2019 - 2009
# values not nan 74 year 2019 - 2008
# values not nan 76 year 2019 - 2007
# values not nan 78 year 2019 - 2006
# values not nan 80 year 2019 - 2005
# values not nan 81 year 2019 - 2004
# values not nan 86 year 2019 - 2003
# values not nan 87 year 2019 - 2002
# values not nan 89 year 2019 - 2001
# values not nan 89 year 2019 - 2000
#                     Country Name Country Code      2019
# 0                          Aruba          ABW       NaN
# 1    Africa Eastern and Southern          AFE       NaN
# 2                    Afghanistan          AFG       NaN
# 3     Africa Western and Central          AFW       NaN
# 4                         Angola          AGO       NaN
# ..                           ...          ...       ...
# 261                       Kosovo          XKX       NaN
# 262                  Yemen, Rep.          YEM       NaN
# 263                 South Africa          ZAF  15.55556
# 264                       Zambia          ZMB       NaN
# 265                     Zimbabwe          ZWE       NaN
#
# [266 rows x 3 columns]

# %% [markdown]
# ## Data for number of children

# %%
df_fertility2019 = pd.read_csv('fertility_rate.csv')[['Country Name', 'Country Code','2019']]
df_fertility2019
# Out:
#                     Country Name Country Code      2019
# 0                          Aruba          ABW  1.486000
# 1    Africa Eastern and Southern          AFE  4.482899
# 2                    Afghanistan          AFG  4.870000
# 3     Africa Western and Central          AFW  5.118932
# 4                         Angola          AGO  5.442000
# ..                           ...          ...       ...
# 261                       Kosovo          XKX  1.546000
# 262                  Yemen, Rep.          YEM  3.963000
# 263                 South Africa          ZAF  2.475000
# 264                       Zambia          ZMB  4.451000
# 265                     Zimbabwe          ZWE  3.599000
#
# [266 rows x 3 columns]

# %% [markdown]
# ## Paper + Minutes spent at home data

# %%
df_cross_country_unpaid = df_cross_country.merge(
    df_f_unpaid2000_to_2019, left_on='isocode', right_on='Country Code', how='left'
).drop(['Country Code', 'Country Name'], axis=1
       ).rename(columns={'2019': 'f_unpaidwk2000_to_2019'}
                ).merge(df_fertility2019, left_on='isocode', right_on='Country Code', how='left').drop(['Country Code', 'Country Name'], axis=1
                                                                                                       ).rename(columns={'2019': 'fertility2019'})

# %% [markdown]
# # Extension 3. Systematic analysis of the most intresting control variables from the Ethnographic Atlas by Murdock

# %% [markdown]
# ## Getting country data for EA, geolocation angle

# %%
isocode2_to3 = pd.read_csv('https://gist.githubusercontent.com/tadast/8827699/raw/f5cac3d42d16b78348610fc4ec301e9234f82821/countries_codes_and_coordinates.csv')[['Alpha-2 code','Alpha-3 code']]
isocode2_to3['Alpha-2 code'] = isocode2_to3['Alpha-2 code'].str[2:4]
isocode2_to3['Alpha-3 code'] = isocode2_to3['Alpha-3 code'].str[2:5]
country_codes = isocode2_to3.set_index('Alpha-2 code').to_dict()['Alpha-3 code']

# %%
# import reverse_geocoder as rg
# df_soc = pd.read_csv('societies.csv')[['id','Lat','Long']]
# df_soc['Country'] = df_soc.apply(lambda row: rg.search((row.Lat,row.Long))[0]['cc'],axis=1)

df_soc = pd.read_csv('df_socc')[['id','Country']]
df_soc['Country'] = df_soc['Country'].replace(country_codes)
df_soc
# Out:
#         id Country
# 0      Aa1     BWA
# 1      Ab1     NaN
# 2     Ad31     KEN
# 3     Ad32     KEN
# 4     Ad33     KEN
# ...    ...     ...
# 1286  Ad29     TZA
# 1287   Ad3     TZA
# 1288  Ad30     KEN
# 1289  Nd26     USA
# 1290  Nd39     USA
#
# [1291 rows x 2 columns]

# %%
df_ea = pd.read_csv('https://raw.githubusercontent.com/D-PLACE/dplace-data/master/datasets/EA/data.csv').merge(df_soc, left_on='soc_id', right_on='id', how='inner').drop(['id'], axis=1)
df_ea
# Out:
#        soc_id          sub_case    year var_id  code comment  \
# 0         Aa1  Nyai Nyae region  1950.0  EA001   8.0     NaN
# 1         Aa1  Nyai Nyae region  1950.0  EA010   9.0     NaN
# 2         Aa1  Nyai Nyae region  1950.0  EA011   2.0     NaN
# 3         Aa1  Nyai Nyae region  1950.0  EA112   1.0     NaN
# 4         Aa1  Nyai Nyae region  1950.0  EA113   2.0     NaN
# ...       ...               ...     ...    ...   ...     ...
# 121349   ec21   Hor River group  1890.0  EA087   8.0     NaN
# 121350   ec21   Hor River group  1890.0  EA088   4.0     NaN
# 121351   ec21   Hor River group  1890.0  EA009   2.0     NaN
# 121352   ec21               NaN     NaN  EA090   NaN     NaN
# 121353   ec21               NaN     NaN  EA094   NaN     NaN
#
#                                                references  \
# 0       biesele1972; biesele1975; biesele1976; draper1...
# 1       biesele1972; biesele1975; biesele1976; draper1...
# 2       biesele1972; biesele1975; biesele1976; draper1...
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 121349  arsenev1926; girfanova2000; ivashchenko1989; k...
# 121350  arsenev1926; girfanova2000; ivashchenko1989; k...
# 121351  arsenev1926; girfanova2000; ivashchenko1989; k...
# 121352                                                NaN
# 121353                                                NaN
#
#                       source_coded_data admin_comment Country
# 0            EthnographicAtlas_1967_p62           NaN     BWA
# 1            EthnographicAtlas_1967_p62           NaN     BWA
# 2            EthnographicAtlas_1967_p62           NaN     BWA
# 3       Gray (1999); Bourguignon (1973)           NaN     BWA
# 4         Gray (1999); Greenbaum (1973)           NaN     BWA
# ...                                 ...           ...     ...
# 121349  Ethnology_Vol43_No1_Winter_2004           NaN     RUS
# 121350  Ethnology_Vol43_No1_Winter_2004           NaN     RUS
# 121351  Ethnology_Vol43_No1_Winter_2004           NaN     RUS
# 121352                              NaN           NaN     RUS
# 121353                              NaN           NaN     RUS
#
# [121354 rows x 10 columns]

# %%
df_ea_codes = pd.read_csv('https://raw.githubusercontent.com/D-PLACE/dplace-data/master/datasets/EA/codes.csv')
df_ea_codes
# Out:
#     var_id  code                                        description  \
# 0    EA001   0.0                       Zero to 5 percent dependence
# 1    EA001   1.0                         6 to 15 percent dependence
# 2    EA001   2.0                        16 to 25 percent dependence
# 3    EA001   3.0                        26 to 35 percent dependence
# 4    EA001   4.0                        36 to 45 percent dependence
# ..     ...   ...                                                ...
# 751  EA112   8.0  No trance states of any kind are known to occu...
# 752  EA113   NaN                                       Missing data
# 753  EA113   1.0  Rigid, characterized as: non-egalitarian, ascr...
# 754  EA113   2.0  Flexible, characterized as: egalitarian, achie...
# 755  EA202   NaN                                       Missing data
#
#                         name
# 0                       0-5%
# 1                      6-15%
# 2                     16-25%
# 3                     26-35%
# 4                     36-45%
# ..                       ...
# 751  No trance or possession
# 752             Missing data
# 753                    Rigid
# 754                 Flexible
# 755             Missing data
#
# [756 rows x 4 columns]

# %%
df_ea = df_ea.merge(df_ea_codes, left_on=['var_id','code'], right_on=['var_id','code'], how='left').rename(columns={'description': 'value_description','name':'value_name'})

# %% [markdown]
# ## Control variable analysis

# %%
df_ea = df_ea.sort_values(by=['var_id','soc_id']).reset_index(drop=True)
df_ea
# Out:
#        soc_id                                  sub_case    year var_id  \
# 0         Aa1                          Nyai Nyae region  1950.0  EA001
# 1         Aa2  with special reference to Central Dorobo  1920.0  EA001
# 2         Aa3                          Gei/Khauan tribe  1840.0  EA001
# 3         Aa4                                       NaN  1920.0  EA001
# 4         Aa5           Epulu net-hunters, Ituri forest  1930.0  EA001
# ...       ...                                       ...     ...    ...
# 121349   ec17                  Upper Amgun' River group  1890.0  EA202
# 121350   ec18                    Ulch people as a whole  1890.0  EA202
# 121351   ec19                            Northern group  1890.0  EA202
# 121352   ec20                   Oroch people as a whole  1890.0  EA202
# 121353   ec21                           Hor River group  1890.0  EA202
#
#           code                  comment  \
# 0          8.0                      NaN
# 1          4.0                      NaN
# 2          1.0                      NaN
# 3          4.0                      NaN
# 4          3.0                      NaN
# ...        ...                      ...
# 121349   420.0  Upper Amgun River group
# 121350  3000.0                      NaN
# 121351   500.0                      NaN
# 121352   800.0                      NaN
# 121353  1300.0                      NaN
#
#                                                references  \
# 0       biesele1972; biesele1975; biesele1976; draper1...
# 1       huntingford1929; huntingford1942; huntingford1...
# 2       hoernl1918; hoernl1925; kohler1970; murdock193...
# 3                  lebzelter1934; schmidt1930; vedder1923
# 4       deleeuwe1966; hart1978; putnam1948; turnbull19...
# ...                                                   ...
# 121349                                                NaN
# 121350                                                NaN
# 121351                                                NaN
# 121352                                                NaN
# 121353                                                NaN
#
#                   source_coded_data admin_comment Country  \
# 0        EthnographicAtlas_1967_p62           NaN     BWA
# 1        EthnographicAtlas_1967_p62           NaN     KEN
# 2        EthnographicAtlas_1967_p62           NaN     NaN
# 3       Ethnology_Vol1_No3_Jul_1962           NaN     NaN
# 4        EthnographicAtlas_1967_p62           NaN     COD
# ...                             ...           ...     ...
# 121349       Korotayev et al., 2004           NaN     RUS
# 121350       Korotayev et al., 2004           NaN     RUS
# 121351       Korotayev et al., 2004           NaN     RUS
# 121352       Korotayev et al., 2004           NaN     RUS
# 121353       Korotayev et al., 2004           NaN     RUS
#
#                   value_description value_name
# 0       76 to 85 percent dependence     76-85%
# 1       36 to 45 percent dependence     36-45%
# 2        6 to 15 percent dependence      6-15%
# 3       36 to 45 percent dependence     36-45%
# 4       26 to 35 percent dependence     26-35%
# ...                             ...        ...
# 121349                          NaN        NaN
# 121350                          NaN        NaN
# 121351                          NaN        NaN
# 121352                          NaN        NaN
# 121353                          NaN        NaN
#
# [121354 rows x 12 columns]

# %%
df_ea = df_ea.drop(['sub_case', 'year','comment','references','source_coded_data','admin_comment','code','soc_id','value_description'], axis=1)

# %%
def md(x):
    if type(x[0]) is np.ndarray:
        if len(x[0]) == 0:
            return np.nan
        return x[0][0]
    else:
        return x

df_ea = df_ea.groupby(['Country','var_id']).agg(pd.Series.mode).apply(md,axis=1).unstack().astype('category').droplevel(0, axis=1).reset_index()
df_ea
# Out:
# var_id Country   EA001   EA002   EA003   EA004   EA005          EA006  \
# 0          AFG    0-5%    0-5%    0-5%  26-35%  56-65%   Bride-wealth
# 1          AGO    0-5%   6-15%   6-15%   6-15%  46-55%   Bride-wealth
# 2          ALB    0-5%    0-5%    0-5%  36-45%  56-65%   Bride-wealth
# 3          ARG  16-25%  16-25%   6-15%    0-5%    0-5%  Bride-service
# 4          ARM    0-5%    0-5%    0-5%  26-35%  66-75%          Dowry
# ..         ...     ...     ...     ...     ...     ...            ...
# 148        WSM    0-5%    0-5%  26-35%   6-15%  56-65%  Gift exchange
# 149        YEM    0-5%    0-5%    0-5%  26-35%  66-75%   Bride-wealth
# 150        ZAF    0-5%   6-15%    0-5%  26-35%  46-55%   Bride-wealth
# 151        ZMB    0-5%   6-15%  16-25%   6-15%  56-65%  Bride-service
# 152        ZWE    0-5%   6-15%   6-15%  16-25%  46-55%   Bride-wealth
#
# var_id         EA007                               EA008  \
# 0              Dowry                      Small extended
# 1       No alternate   Polygyny, typical cowives pattern
# 2       No alternate                      Small extended
# 3       No alternate                      Small extended
# 4       No alternate                      Large extended
# ..               ...                                 ...
# 148     No alternate                      Large extended
# 149     No alternate                      Small extended
# 150     No alternate   Polygyny, typical cowives pattern
# 151     No alternate   Polygyny, typical cowives pattern
# 152     No alternate  Polygyny, atypical cowives pattern
#
# var_id                                    EA009  ...              EA085  \
# 0                              Limited polygyny  ...       Missing data
# 1       Polygyny, non-sororal separate quarters  ...       Missing data
# 2                 Polygyny, non-sororal cohabit  ...  Elevated slightly
# 3                              Limited polygyny  ...       Missing data
# 4                                    Monogamous  ...       Missing data
# ..                                          ...  ...                ...
# 148                            Limited polygyny  ...       Missing data
# 149               Polygyny, non-sororal cohabit  ...       Missing data
# 150     Polygyny, non-sororal separate quarters  ...       Missing data
# 151     Polygyny, non-sororal separate quarters  ...       Missing data
# 152     Polygyny, non-sororal separate quarters  ...       Missing data
#
# var_id                   EA086         EA087                    EA088  \
# 0                 Missing data  Missing data             Missing data
# 1                 Missing data  Missing data             Missing data
# 2       Stone, stucco or brick    Two slopes      Tile or fired brick
# 3                 Missing data  Missing data  Grass, leaves or thatch
# 4                 Missing data  Missing data             Missing data
# ..                         ...           ...                      ...
# 148               Missing data  Missing data             Missing data
# 149               Missing data  Missing data             Missing data
# 150               Missing data  Missing data             Missing data
# 151               Missing data  Missing data             Missing data
# 152               Missing data  Missing data             Missing data
#
# var_id                   EA090             EA094  \
# 0               Minimal states      Missing data
# 1                 Missing data      Missing data
# 2               Minimal states  Patrilineal, son
# 3       Autonomous communities      Missing data
# 4                 Missing data      Missing data
# ..                         ...               ...
# 148             Minimal states      Missing data
# 149               Missing data      Missing data
# 150               Missing data      Missing data
# 151               Missing data      Missing data
# 152               Missing data      Missing data
#
# var_id                                             EA112         EA113  \
# 0                                           Missing data  Missing data
# 1               T due to P only; P explains T and others  Missing data
# 2                                           Missing data  Missing data
# 3       Two T states, one due to P; P expl. T and others  Missing data
# 4                                No trance or possession  Missing data
# ..                                                   ...           ...
# 148                                         Missing data  Missing data
# 149                                Trance, no possession  Missing data
# 150                                         Missing data  Missing data
# 151                                         Missing data  Missing data
# 152             T due to P only; P explains T and others  Missing data
#
# var_id      EA201         EA202
# 0            Same           NaN
# 1            Same  Missing data
# 2            Same  Missing data
# 3            Same  Missing data
# 4            Same  Missing data
# ..            ...           ...
# 148          Same  Missing data
# 149          Same           NaN
# 150          Same  Missing data
# 151     Different  Missing data
# 152          Same           NaN
#
# [153 rows x 95 columns]

# %%
columns_used_paper=['EA030','EA033','EA028','EA075','EA012','EA008','EA002','EA004']
df_ea = df_ea.drop(columns_used_paper, axis=1)

# %%
df_cross_country_ea = df_cross_country.merge(df_ea, left_on='isocode', right_on='Country', how='left').drop(['Country'], axis=1)
df_cross_country_ea
# Out:
#     isocode  flfp2000  female_ownership  women_politics      plow  \
# 0       ABW       NaN               NaN             NaN  0.000000
# 1       AFG      31.3               2.8             NaN  0.999969
# 2       AGO      75.2              56.6            16.0  0.000000
# 3       AIA       NaN               NaN             NaN  0.000000
# 4       ALB      50.2              10.8             5.0  1.000000
# ..      ...       ...               ...             ...       ...
# 229     YUG       NaN              28.8             NaN  1.000000
# 230     ZAF      44.3              22.6            30.0  0.540551
# 231     ZAR      55.5              38.9             NaN  0.000000
# 232     ZMB      62.1              37.2            10.0  0.000000
# 233     ZWE      64.0              56.2            14.0  0.000002
#
#      agricultural_suitability  tropical_climate  large_animals  \
# 0                    0.829847          1.000000       1.000000
# 1                    0.229267          0.785295       1.000000
# 2                    0.921061          1.000000       0.998896
# 3                    0.829847          1.000000       1.000000
# 4                    0.555928          0.359318       1.000000
# ..                        ...               ...            ...
# 229                  0.775941          0.080989       1.000000
# 230                  0.865508          0.901535       0.999999
# 231                  0.423659          1.000000       0.928739
# 232                  0.955900          1.000000       0.754301
# 233                  0.913061          1.000000       0.994593
#
#      political_hierarchies  economic_complexity  ...              EA085  \
# 0                 4.000000             7.000000  ...                NaN
# 1                 3.633688             6.199330  ...       Missing data
# 2                 2.720727             6.697217  ...       Missing data
# 3                 4.000000             7.000000  ...                NaN
# 4                 3.029723             5.035051  ...  Elevated slightly
# ..                     ...                  ...  ...                ...
# 229               3.822862             7.444995  ...                NaN
# 230               3.550035             5.920460  ...       Missing data
# 231               2.383938             6.545618  ...                NaN
# 232               2.390349             5.871349  ...       Missing data
# 233               3.104864             6.337659  ...       Missing data
#
#                       EA086         EA087                EA088  \
# 0                       NaN           NaN                  NaN
# 1              Missing data  Missing data         Missing data
# 2              Missing data  Missing data         Missing data
# 3                       NaN           NaN                  NaN
# 4    Stone, stucco or brick    Two slopes  Tile or fired brick
# ..                      ...           ...                  ...
# 229                     NaN           NaN                  NaN
# 230            Missing data  Missing data         Missing data
# 231                     NaN           NaN                  NaN
# 232            Missing data  Missing data         Missing data
# 233            Missing data  Missing data         Missing data
#
#               EA090             EA094  \
# 0               NaN               NaN
# 1    Minimal states      Missing data
# 2      Missing data      Missing data
# 3               NaN               NaN
# 4    Minimal states  Patrilineal, son
# ..              ...               ...
# 229             NaN               NaN
# 230    Missing data      Missing data
# 231             NaN               NaN
# 232    Missing data      Missing data
# 233    Missing data      Missing data
#
#                                         EA112         EA113      EA201  \
# 0                                         NaN           NaN        NaN
# 1                                Missing data  Missing data       Same
# 2    T due to P only; P explains T and others  Missing data       Same
# 3                                         NaN           NaN        NaN
# 4                                Missing data  Missing data       Same
# ..                                        ...           ...        ...
# 229                                       NaN           NaN        NaN
# 230                              Missing data  Missing data       Same
# 231                                       NaN           NaN        NaN
# 232                              Missing data  Missing data  Different
# 233  T due to P only; P explains T and others  Missing data       Same
#
#             EA202
# 0             NaN
# 1             NaN
# 2    Missing data
# 3             NaN
# 4    Missing data
# ..            ...
# 229           NaN
# 230  Missing data
# 231           NaN
# 232  Missing data
# 233           NaN
#
# [234 rows x 144 columns]

# %%
def avg_VIF(df):
    avg_VIF = pd.DataFrame()
    avg_VIF["avg_VIF Factor"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    avg_VIF["features"] = df.columns
    return avg_VIF[avg_VIF["features"].str.startswith('EA')]["avg_VIF Factor"].mean()

# %% [markdown]
# ### Best control variable for table 3

# %%
function_dict = {'predictor': [], 'gain in r^2 adj': [], 'avg_VIF': []}
best = list()
base_rsq = smf.ols(formula='flfp2000 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity',
                   data=df_cross_country_ea).fit(cov_type='HC1').rsquared_adj
base_cols = ['plow', 'agricultural_suitability', 'tropical_climate',
             'large_animals', 'political_hierarchies', 'economic_complexity']
outcome = "flfp2000 ~  "
base_form = 'plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity'

for column in df_cross_country_ea.columns:
    if column.startswith('EA'):

        res = smf.ols(formula=outcome+base_form +
                      f'+ C({column})', data=df_cross_country_ea).fit(cov_type='HC1')

        function_dict['gain in r^2 adj'].append(res.rsquared_adj-base_rsq)
        function_dict['predictor'].append(column)
        function_dict['avg_VIF'].append(
            avg_VIF(
                pd.get_dummies(
                    df_cross_country_ea[base_cols + [column]]
                ).dropna()))

# %%
var_dict = pd.read_csv('https://raw.githubusercontent.com/D-PLACE/dplace-data/master/datasets/EA/variables.csv')[['id','title']].set_index('id').to_dict()['title']

# %%
function_df = pd.DataFrame(function_dict).sort_values(
    by=['gain in r^2 adj'], ascending=False)

best.append(function_df['predictor'].iloc[0])

sns.barplot(x='gain in r^2 adj', y='predictor', data=function_df.replace(var_dict).head(10))
plt.title('Top control variable candidates for table3, flfp2000')
# Out:
# Text(0.5, 1.0, 'Top control variable candidates for table3, flfp2000')

# %% [markdown]
# ### Best second control variable for table 3

# %%
for column in df_cross_country_ea.columns:
    if column.startswith('EA') and column != best[0]:
        
        res = smf.ols(formula=outcome+base_form+f'+ C({column}) + C({best[0]})', data=df_cross_country_ea).fit(cov_type='HC1')

        function_dict['gain in r^2 adj'].append(res.rsquared_adj-base_rsq)
        function_dict['predictor'].append(column)
        function_dict['avg_VIF'].append(
            avg_VIF(
                pd.get_dummies(
                    df_cross_country_ea[base_cols + [column] + [best[0]]]
                ).dropna()))

# %%
function_df = pd.DataFrame(function_dict).sort_values(
    by=['gain in r^2 adj'], ascending=False)

best.append(function_df['predictor'].iloc[0])

sns.barplot(x='gain in r^2 adj', y='predictor', data=function_df.replace(var_dict).head(10))
plt.title('Top 2nd control for table3, flfp2000')
# Out:
# Text(0.5, 1.0, 'Top 2nd control for table3, flfp2000')

# %% [markdown]
# ### Best third control for table 3

# %%
for column in df_cross_country_ea.columns:
    if column.startswith('EA') and column != best[0] and column != best[1]:
        
        res = smf.ols(formula=outcome+base_form+f'+ C({column}) + C({best[0]}) + C({best[1]})', data=df_cross_country_ea).fit(cov_type='HC1')

        function_dict['gain in r^2 adj'].append(res.rsquared_adj-base_rsq)
        function_dict['predictor'].append(column)
        function_dict['avg_VIF'].append(
            avg_VIF(
                pd.get_dummies(
                    df_cross_country_ea[base_cols + [column] + [best[0]] + [best[1]]]
                ).dropna()))

# %%
function_df = pd.DataFrame(function_dict).sort_values(
    by=['gain in r^2 adj'], ascending=False)

best.append(function_df['predictor'].iloc[0])

sns.barplot(x='gain in r^2 adj', y='predictor', data=function_df.replace(var_dict).head(10))
plt.title('Top 3rd control for table3, flfp2000')
# Out:
# Text(0.5, 1.0, 'Top 3rd control for table3, flfp2000')

# %% [markdown]
# # Addendum after the presentation analyses

# %% [markdown]
# ## Addendum Extension 1. Replicating the claimed data in the paper

# %% [markdown]
# <img src="flfp_source_in_appendix.png">

# %%
flfp2000_wb = df_wb[df_wb['Series Name'] == 'Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)']['2000 [YR2000]'].reset_index()
flfp2000_wb
# Out:
#               Country Name Country Code 2000 [YR2000]
# 0              Afghanistan          AFG         15.35
# 1                  Albania          ALB         57.89
# 2                  Algeria          DZA         12.71
# 3           American Samoa          ASM            ..
# 4                  Andorra          AND            ..
# ..                     ...          ...           ...
# 212  Virgin Islands (U.S.)          VIR         65.72
# 213     West Bank and Gaza          PSE          12.9
# 214            Yemen, Rep.          YEM         21.29
# 215                 Zambia          ZMB         73.73
# 216               Zimbabwe          ZWE         72.74
#
# [217 rows x 3 columns]

# %%
! head -6 flfp2000_wb.csv | tail -1
# Out:
# "Aruba","ABW","Labor force participation rate, female (% of female population ages 15-64) (modeled ILO estimate)","SL.TLF.ACTI.FE.ZS","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","",

# %%
flfp2000_wb_2 = pd.read_csv('flfp2000_wb.csv',skiprows=[0,1,2])[['Country Code','2000']]
flfp2000_wb_2
# Out:
#     Country Code       2000
# 0            ABW        NaN
# 1            AFE  67.371616
# 2            AFG  15.350000
# 3            AFW  59.577898
# 4            AGO  76.490000
# ..           ...        ...
# 261          XKX        NaN
# 262          YEM  21.290000
# 263          ZAF  48.220000
# 264          ZMB  73.730000
# 265          ZWE  72.740000
#
# [266 rows x 2 columns]

# %%
flfp2000_wb.merge(flfp2000_wb_2, left_on='Country Code', right_on='Country Code', how='left').drop(['Country Code'], axis=1)
# Out:
#               Country Name 2000 [YR2000]   2000
# 0              Afghanistan         15.35  15.35
# 1                  Albania         57.89  57.89
# 2                  Algeria         12.71  12.71
# 3           American Samoa            ..    NaN
# 4                  Andorra            ..    NaN
# ..                     ...           ...    ...
# 212  Virgin Islands (U.S.)         65.72  65.72
# 213     West Bank and Gaza          12.9  12.90
# 214            Yemen, Rep.         21.29  21.29
# 215                 Zambia         73.73  73.73
# 216               Zimbabwe         72.74  72.74
#
# [217 rows x 3 columns]

# %% [markdown]
# Data provided in paper zip

# %%
df_cross_country_flfpcomp = df_cross_country.merge(flfp2000_wb, left_on='isocode', right_on='Country Code', how='left').drop(['Country Name','Country Code'], axis=1).rename(columns={'2000 [YR2000]': 'flfp2000_wb'})
df_cross_country_flfpcomp['flfp2000_wb'] = df_cross_country_flfpcomp['flfp2000_wb'].replace('..',np.nan).astype(float)
df_cross_country_flfpcomp
# Out:
#     isocode  flfp2000  female_ownership  women_politics      plow  \
# 0       ABW       NaN               NaN             NaN  0.000000
# 1       AFG      31.3               2.8             NaN  0.999969
# 2       AGO      75.2              56.6            16.0  0.000000
# 3       AIA       NaN               NaN             NaN  0.000000
# 4       ALB      50.2              10.8             5.0  1.000000
# ..      ...       ...               ...             ...       ...
# 229     YUG       NaN              28.8             NaN  1.000000
# 230     ZAF      44.3              22.6            30.0  0.540551
# 231     ZAR      55.5              38.9             NaN  0.000000
# 232     ZMB      62.1              37.2            10.0  0.000000
# 233     ZWE      64.0              56.2            14.0  0.000002
#
#      agricultural_suitability  tropical_climate  large_animals  \
# 0                    0.829847          1.000000       1.000000
# 1                    0.229267          0.785295       1.000000
# 2                    0.921061          1.000000       0.998896
# 3                    0.829847          1.000000       1.000000
# 4                    0.555928          0.359318       1.000000
# ..                        ...               ...            ...
# 229                  0.775941          0.080989       1.000000
# 230                  0.865508          0.901535       0.999999
# 231                  0.423659          1.000000       0.928739
# 232                  0.955900          1.000000       0.754301
# 233                  0.913061          1.000000       0.994593
#
#      political_hierarchies  economic_complexity  ...   avg_temp2  \
# 0                 4.000000             7.000000  ...  694.377380
# 1                 3.633688             6.199330  ...   74.482773
# 2                 2.720727             6.697217  ...  418.034027
# 3                 4.000000             7.000000  ...  694.377380
# 4                 3.029723             5.035051  ...  122.236977
# ..                     ...                  ...  ...         ...
# 229               3.822862             7.444995  ...  116.812553
# 230               3.550035             5.920460  ...  312.183350
# 231               2.383938             6.545618  ...  546.375610
# 232               2.390349             5.871349  ...  442.156647
# 233               3.104864             6.337659  ...  406.286194
#
#       avg_precip2  slope_soil  slope_temp  slope_precip  soil_temp  \
# 0     9291.514648    4.304165  127.054840    464.768494  23.523033
# 1      538.041870    6.531851  215.510483    579.226624   2.257479
# 2     9126.774414   18.654472  387.178406   1809.105957  20.141113
# 3     9291.514648    4.304165  127.054840    464.768494  23.523033
# 4     6294.060547   24.525124  347.221527   2491.556885   8.633903
# ..            ...         ...         ...           ...        ...
# 229   4452.978027   20.765686  257.512268   1589.931641   9.419717
# 230   4103.467285   21.043222  430.698578   1561.507446  15.252764
# 231  15426.306641   10.083570  239.301346   1271.541260  23.022926
# 232   7636.923828   11.142666  247.966599   1030.538818  19.868818
# 233   2897.081787   18.047073  385.386444   1029.107666  19.025778
#
#      soil_precip  temp_precip       aes  flfp2000_wb
# 0      86.047607  2540.042725       NaN          NaN
# 1       6.067417   200.187042       NaN        15.35
# 2      94.110115  1953.279907  3.473401        76.49
# 3      86.047607  2540.042725       NaN          NaN
# 4      61.954281   877.135620  1.537784        57.89
# ..           ...          ...       ...          ...
# 229    58.159191   721.223755       NaN          NaN
# 230    55.299240  1131.827759  2.816762        48.22
# 231   122.333626  2903.197754       NaN          NaN
# 232    82.573975  1837.584473  2.535204        73.73
# 233    50.805035  1084.916748  3.126542        72.74
#
# [234 rows x 59 columns]

# %%
m_flfp_paper = smf.ols(formula='flfp2000 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country).fit(cov_type='HC1')
m_flfp_wb = smf.ols(formula='flfp2000_wb ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country_flfpcomp).fit(cov_type='HC1')
stargazer = Stargazer([m_flfp_paper, m_flfp_wb])
stargazer.custom_columns(['F_lab_part2000 paper', 'F_lab_part2000 found in wb'],[1,1])
stargazer
# Out:
# <table style="text-align:center"><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">F_lab_part2000 paper</td><td colspan="1">F_lab_part2000 found in wb</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td></tr><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">Intercept</td><td>51.658<sup>***</sup></td><td>59.879<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(6.338)</td><td>(7.837)</td></tr><tr><td style="text-align:left">agricultural_suitability</td><td>9.407<sup>**</sup></td><td>8.482<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td>(3.885)</td><td>(4.046)</td></tr><tr><td style="text-align:left">economic_complexity</td><td>0.170<sup></sup></td><td>1.513<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.849)</td><td>(1.002)</td></tr><tr><td style="text-align:left">large_animals</td><td>10.903<sup>**</sup></td><td>7.446<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(5.032)</td><td>(5.978)</td></tr><tr><td style="text-align:left">plow</td><td>-14.895<sup>***</sup></td><td>-14.443<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(3.318)</td><td>(3.838)</td></tr><tr><td style="text-align:left">political_hierarchies</td><td>-0.787<sup></sup></td><td>-1.667<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(1.622)</td><td>(1.705)</td></tr><tr><td style="text-align:left">tropical_climate</td><td>-8.644<sup>***</sup></td><td>-16.702<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(2.698)</td><td>(3.050)</td></tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>177</td><td>175</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.222</td><td>0.241</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.195</td><td>0.214</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>13.980 (df=170)</td><td>15.661 (df=168)</td></tr><tr><td style="text-align: left">F Statistic</td><td>7.306<sup>***</sup> (df=6; 170)</td><td>8.214<sup>***</sup> (df=6; 168)</td></tr><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="2" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# ## Addendum Extension 2. New outcome variable: orthogonality with the paper outcome variables, and some transformations to try and capture more variance.

# %% [markdown]
# ### Is the new outcome variable f_unpaidwk2000_to_2019 orthogonal to the previous outcomes?

# %%
corr_matrix = np.corrcoef(df_cross_country_unpaid[['flfp2000', 'f_unpaidwk2000_to_2019','female_ownership','women_politics']].dropna().T)
sm.graphics.plot_corr(corr_matrix, xnames=df_cross_country_unpaid[['flfp2000', 'f_unpaidwk2000_to_2019','female_ownership','women_politics']].columns)
plt.title('Correlation Matrix for Outcomes')
plt.show()

# %%
df_cross_country_unpaid[['flfp2000', 'f_unpaidwk2000_to_2019','female_ownership','women_politics']].corr()
# Out:
#                         flfp2000  f_unpaidwk2000_to_2019  female_ownership  \
# flfp2000                1.000000               -0.370693          0.256966
# f_unpaidwk2000_to_2019 -0.370693                1.000000         -0.262461
# female_ownership        0.256966               -0.262461          1.000000
# women_politics          0.089557               -0.043742          0.007961
#
#                         women_politics
# flfp2000                      0.089557
# f_unpaidwk2000_to_2019       -0.043742
# female_ownership              0.007961
# women_politics                1.000000

# %% [markdown]
# Answer is to a great extent (corr only ranges from 0.37-0.04). As expected, the correlation is negative - the more females do unpaid work the less they tend to participate in the labour force and own businesses.

# %% [markdown]
# ### Can transforming the new outcome variable improve the fit of the model, and allow to see a fairer picture of whether plow expalins any variance?

# %%
df_m_unpaid = pd.read_csv('male_unpaid_work.csv', skiprows=[0,1,2]).drop(['Indicator Name', 'Indicator Code','Unnamed: 66'],axis=1).iloc[:,:-2]
df_m_unpaid
# Out:
#                     Country Name Country Code  1960  1961  1962  1963  1964  \
# 0                          Aruba          ABW   NaN   NaN   NaN   NaN   NaN
# 1    Africa Eastern and Southern          AFE   NaN   NaN   NaN   NaN   NaN
# 2                    Afghanistan          AFG   NaN   NaN   NaN   NaN   NaN
# 3     Africa Western and Central          AFW   NaN   NaN   NaN   NaN   NaN
# 4                         Angola          AGO   NaN   NaN   NaN   NaN   NaN
# ..                           ...          ...   ...   ...   ...   ...   ...
# 261                       Kosovo          XKX   NaN   NaN   NaN   NaN   NaN
# 262                  Yemen, Rep.          YEM   NaN   NaN   NaN   NaN   NaN
# 263                 South Africa          ZAF   NaN   NaN   NaN   NaN   NaN
# 264                       Zambia          ZMB   NaN   NaN   NaN   NaN   NaN
# 265                     Zimbabwe          ZWE   NaN   NaN   NaN   NaN   NaN
#
#      1965  1966  1967  ...     2010  2011  2012  2013  2014  2015  2016  2017  \
# 0     NaN   NaN   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     NaN   NaN   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     NaN   NaN   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN   NaN   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     NaN   NaN   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..    ...   ...   ...  ...      ...   ...   ...   ...   ...   ...   ...   ...
# 261   NaN   NaN   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262   NaN   NaN   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 263   NaN   NaN   NaN  ...  6.45833   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 264   NaN   NaN   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 265   NaN   NaN   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      2018  2019
# 0     NaN   NaN
# 1     NaN   NaN
# 2     NaN   NaN
# 3     NaN   NaN
# 4     NaN   NaN
# ..    ...   ...
# 261   NaN   NaN
# 262   NaN   NaN
# 263   NaN   NaN
# 264   NaN   NaN
# 265   NaN   NaN
#
# [266 rows x 62 columns]

# %%
for col in range(-2, -21, -1):
    df_m_unpaid['2019'] = df_m_unpaid['2019'].fillna(
        df_m_unpaid.iloc[:, col])
    print('values not nan', df_m_unpaid['2019'].notna(
    ).sum(), 'year 2019 -', df_m_unpaid.iloc[:, col].name)

df_m_unpaid2000_to_2019 = df_m_unpaid[['Country Name', 'Country Code', '2019']]
df_m_unpaid2000_to_2019
# Out:
# values not nan 7 year 2019 - 2018
# values not nan 13 year 2019 - 2017
# values not nan 20 year 2019 - 2016
# values not nan 31 year 2019 - 2015
# values not nan 37 year 2019 - 2014
# values not nan 46 year 2019 - 2013
# values not nan 52 year 2019 - 2012
# values not nan 56 year 2019 - 2011
# values not nan 66 year 2019 - 2010
# values not nan 71 year 2019 - 2009
# values not nan 74 year 2019 - 2008
# values not nan 76 year 2019 - 2007
# values not nan 78 year 2019 - 2006
# values not nan 80 year 2019 - 2005
# values not nan 81 year 2019 - 2004
# values not nan 86 year 2019 - 2003
# values not nan 87 year 2019 - 2002
# values not nan 89 year 2019 - 2001
# values not nan 89 year 2019 - 2000
#                     Country Name Country Code     2019
# 0                          Aruba          ABW      NaN
# 1    Africa Eastern and Southern          AFE      NaN
# 2                    Afghanistan          AFG      NaN
# 3     Africa Western and Central          AFW      NaN
# 4                         Angola          AGO      NaN
# ..                           ...          ...      ...
# 261                       Kosovo          XKX      NaN
# 262                  Yemen, Rep.          YEM      NaN
# 263                 South Africa          ZAF  6.45833
# 264                       Zambia          ZMB      NaN
# 265                     Zimbabwe          ZWE      NaN
#
# [266 rows x 3 columns]

# %%
df_cross_country_unpaid_mf = df_cross_country_unpaid.merge(
    df_m_unpaid2000_to_2019, left_on='isocode', right_on='Country Code', how='left'
).drop(['Country Code', 'Country Name'], axis=1
       ).rename(columns={'2019': 'm_unpaid2000_to_2019'})
df_cross_country_unpaid_mf
# Out:
#     isocode  flfp2000  female_ownership  women_politics      plow  \
# 0       ABW       NaN               NaN             NaN  0.000000
# 1       AFG      31.3               2.8             NaN  0.999969
# 2       AGO      75.2              56.6            16.0  0.000000
# 3       AIA       NaN               NaN             NaN  0.000000
# 4       ALB      50.2              10.8             5.0  1.000000
# ..      ...       ...               ...             ...       ...
# 229     YUG       NaN              28.8             NaN  1.000000
# 230     ZAF      44.3              22.6            30.0  0.540551
# 231     ZAR      55.5              38.9             NaN  0.000000
# 232     ZMB      62.1              37.2            10.0  0.000000
# 233     ZWE      64.0              56.2            14.0  0.000002
#
#      agricultural_suitability  tropical_climate  large_animals  \
# 0                    0.829847          1.000000       1.000000
# 1                    0.229267          0.785295       1.000000
# 2                    0.921061          1.000000       0.998896
# 3                    0.829847          1.000000       1.000000
# 4                    0.555928          0.359318       1.000000
# ..                        ...               ...            ...
# 229                  0.775941          0.080989       1.000000
# 230                  0.865508          0.901535       0.999999
# 231                  0.423659          1.000000       0.928739
# 232                  0.955900          1.000000       0.754301
# 233                  0.913061          1.000000       0.994593
#
#      political_hierarchies  economic_complexity  ...  slope_soil  slope_temp  \
# 0                 4.000000             7.000000  ...    4.304165  127.054840
# 1                 3.633688             6.199330  ...    6.531851  215.510483
# 2                 2.720727             6.697217  ...   18.654472  387.178406
# 3                 4.000000             7.000000  ...    4.304165  127.054840
# 4                 3.029723             5.035051  ...   24.525124  347.221527
# ..                     ...                  ...  ...         ...         ...
# 229               3.822862             7.444995  ...   20.765686  257.512268
# 230               3.550035             5.920460  ...   21.043222  430.698578
# 231               2.383938             6.545618  ...   10.083570  239.301346
# 232               2.390349             5.871349  ...   11.142666  247.966599
# 233               3.104864             6.337659  ...   18.047073  385.386444
#
#      slope_precip  soil_temp  soil_precip  temp_precip       aes  \
# 0      464.768494  23.523033    86.047607  2540.042725       NaN
# 1      579.226624   2.257479     6.067417   200.187042       NaN
# 2     1809.105957  20.141113    94.110115  1953.279907  3.473401
# 3      464.768494  23.523033    86.047607  2540.042725       NaN
# 4     2491.556885   8.633903    61.954281   877.135620  1.537784
# ..            ...        ...          ...          ...       ...
# 229   1589.931641   9.419717    58.159191   721.223755       NaN
# 230   1561.507446  15.252764    55.299240  1131.827759  2.816762
# 231   1271.541260  23.022926   122.333626  2903.197754       NaN
# 232   1030.538818  19.868818    82.573975  1837.584473  2.535204
# 233   1029.107666  19.025778    50.805035  1084.916748  3.126542
#
#      f_unpaidwk2000_to_2019  fertility2019  m_unpaid2000_to_2019
# 0                       NaN          1.486                   NaN
# 1                       NaN          4.870                   NaN
# 2                       NaN          5.442                   NaN
# 3                       NaN            NaN                   NaN
# 4                  21.73611          1.414               3.47222
# ..                      ...            ...                   ...
# 229                     NaN            NaN                   NaN
# 230                15.55556          2.475               6.45833
# 231                     NaN            NaN                   NaN
# 232                     NaN          4.451                   NaN
# 233                     NaN          3.599                   NaN
#
# [234 rows x 61 columns]

# %% [markdown]
# Interpretation: for every unpaid hour worked by females, what percentage of that hour would males work in a given country? Male unpaid work / female unpaid work (in %)

# %%
df_cross_country_unpaid_mf['mfratio_unpaid2000_to_2019'] = df_cross_country_unpaid_mf['m_unpaid2000_to_2019']/df_cross_country_unpaid_mf['f_unpaidwk2000_to_2019']*100
df_cross_country_unpaid_mf
# Out:
#     isocode  flfp2000  female_ownership  women_politics      plow  \
# 0       ABW       NaN               NaN             NaN  0.000000
# 1       AFG      31.3               2.8             NaN  0.999969
# 2       AGO      75.2              56.6            16.0  0.000000
# 3       AIA       NaN               NaN             NaN  0.000000
# 4       ALB      50.2              10.8             5.0  1.000000
# ..      ...       ...               ...             ...       ...
# 229     YUG       NaN              28.8             NaN  1.000000
# 230     ZAF      44.3              22.6            30.0  0.540551
# 231     ZAR      55.5              38.9             NaN  0.000000
# 232     ZMB      62.1              37.2            10.0  0.000000
# 233     ZWE      64.0              56.2            14.0  0.000002
#
#      agricultural_suitability  tropical_climate  large_animals  \
# 0                    0.829847          1.000000       1.000000
# 1                    0.229267          0.785295       1.000000
# 2                    0.921061          1.000000       0.998896
# 3                    0.829847          1.000000       1.000000
# 4                    0.555928          0.359318       1.000000
# ..                        ...               ...            ...
# 229                  0.775941          0.080989       1.000000
# 230                  0.865508          0.901535       0.999999
# 231                  0.423659          1.000000       0.928739
# 232                  0.955900          1.000000       0.754301
# 233                  0.913061          1.000000       0.994593
#
#      political_hierarchies  economic_complexity  ...  slope_temp  \
# 0                 4.000000             7.000000  ...  127.054840
# 1                 3.633688             6.199330  ...  215.510483
# 2                 2.720727             6.697217  ...  387.178406
# 3                 4.000000             7.000000  ...  127.054840
# 4                 3.029723             5.035051  ...  347.221527
# ..                     ...                  ...  ...         ...
# 229               3.822862             7.444995  ...  257.512268
# 230               3.550035             5.920460  ...  430.698578
# 231               2.383938             6.545618  ...  239.301346
# 232               2.390349             5.871349  ...  247.966599
# 233               3.104864             6.337659  ...  385.386444
#
#      slope_precip  soil_temp  soil_precip  temp_precip       aes  \
# 0      464.768494  23.523033    86.047607  2540.042725       NaN
# 1      579.226624   2.257479     6.067417   200.187042       NaN
# 2     1809.105957  20.141113    94.110115  1953.279907  3.473401
# 3      464.768494  23.523033    86.047607  2540.042725       NaN
# 4     2491.556885   8.633903    61.954281   877.135620  1.537784
# ..            ...        ...          ...          ...       ...
# 229   1589.931641   9.419717    58.159191   721.223755       NaN
# 230   1561.507446  15.252764    55.299240  1131.827759  2.816762
# 231   1271.541260  23.022926   122.333626  2903.197754       NaN
# 232   1030.538818  19.868818    82.573975  1837.584473  2.535204
# 233   1029.107666  19.025778    50.805035  1084.916748  3.126542
#
#      f_unpaidwk2000_to_2019  fertility2019  m_unpaid2000_to_2019  \
# 0                       NaN          1.486                   NaN
# 1                       NaN          4.870                   NaN
# 2                       NaN          5.442                   NaN
# 3                       NaN            NaN                   NaN
# 4                  21.73611          1.414               3.47222
# ..                      ...            ...                   ...
# 229                     NaN            NaN                   NaN
# 230                15.55556          2.475               6.45833
# 231                     NaN            NaN                   NaN
# 232                     NaN          4.451                   NaN
# 233                     NaN          3.599                   NaN
#
#      mfratio_unpaid2000_to_2019
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                     15.974431
# ..                          ...
# 229                         NaN
# 230                   41.517824
# 231                         NaN
# 232                         NaN
# 233                         NaN
#
# [234 rows x 62 columns]

# %% [markdown]
# Mean proportion of unpaid work of males vs females:

# %%
df_cross_country_unpaid_mf['mfratio_unpaid2000_to_2019'].mean()
# Out:
# 40.96360567606768

# %%
df_cross_country_unpaid_mf.sort_values(by='mfratio_unpaid2000_to_2019', ascending=False).head(10)
# Out:
#     isocode  flfp2000  female_ownership  women_politics      plow  \
# 156     NOR      61.4               NaN            36.0  0.988669
# 195     SWE      58.2               NaN            43.0  0.997220
# 114     LAO      79.5              39.4            21.0  0.594234
# 56      DNK      60.1               NaN            37.0  1.000000
# 66      FIN      58.3               NaN            37.0  0.998373
# 34      CAN      58.6               NaN            21.0  0.974251
# 36      CHE      57.7               NaN            23.0  1.000000
# 53      DEU      49.1              20.3            31.0  1.000000
# 16      BEL      43.5               NaN            23.0  1.000000
# 217     USA      59.5               NaN            13.0  0.972528
#
#      agricultural_suitability  tropical_climate  large_animals  \
# 156                  0.757518          0.000000       1.000000
# 195                  0.804468          0.000000       1.000000
# 114                  0.206441          0.999877       1.000000
# 56                   0.806186          0.000000       1.000000
# 66                   0.904182          0.000000       1.000000
# 34                   0.811269          0.000153       0.977235
# 36                   0.779485          0.072393       1.000000
# 53                   0.809065          0.000000       1.000000
# 16                   0.872731          0.000000       1.000000
# 217                  0.855395          0.043982       0.994987
#
#      political_hierarchies  economic_complexity  ...  slope_temp  \
# 156               3.966026             6.932013  ...   45.694183
# 195               3.991660             6.983320  ...   45.506477
# 114               3.448479             6.416276  ...  429.415710
# 56                4.000000             7.000000  ...   45.124153
# 66                3.995349             6.990236  ...   87.894867
# 34                3.943073             7.634878  ...  106.546814
# 36                4.436066             7.000000  ...   81.196999
# 53                4.000737             7.000000  ...   45.358215
# 16                4.487379             7.000000  ...   71.537491
# 217               3.949898             7.927381  ...  142.810471
#
#      slope_precip  soil_temp  soil_precip  temp_precip       aes  \
# 156    364.859222   8.725794    69.673782   658.970825       NaN
# 195    361.196899   8.811407    69.938454   667.939575       NaN
# 114   2571.993408  15.324376    91.785637  3564.690430  3.477813
# 56     358.693420   8.827337    70.168800   671.338928       NaN
# 66     455.054260  10.222527    52.924641   586.771118       NaN
# 34    1435.098633   5.902040    79.495659   603.197266       NaN
# 36     613.612610   8.258326    62.408867   709.708130       NaN
# 53     360.445892   8.823294    70.115639   670.729858  2.925299
# 16     562.541809   8.058365    63.367710   689.432983       NaN
# 217   1467.278320   8.443326    86.749306   775.879700       NaN
#
#      f_unpaidwk2000_to_2019  fertility2019  m_unpaid2000_to_2019  \
# 156                15.30833          1.530              12.33333
# 195                16.04201          1.710              12.82797
# 114                13.60380          2.571              10.06278
# 56                 15.62500          1.700              11.25000
# 66                 15.20417          1.350              10.49167
# 34                 14.58333          1.470               9.58333
# 36                 16.83333          1.480              10.80417
# 53                 16.40000          1.540              10.40000
# 16                 15.90278          1.600              10.06944
# 217                15.33333          1.706               9.66667
#
#      mfratio_unpaid2000_to_2019
# 156                   80.566136
# 195                   79.964855
# 114                   73.970361
# 56                    72.000000
# 66                    69.005214
# 34                    65.714278
# 36                    64.183201
# 53                    63.414634
# 16                    63.318740
# 217                   63.043514
#
# [10 rows x 62 columns]

# %% [markdown]
# #### Regression Results

# %%
mfratio = smf.ols(formula='mfratio_unpaid2000_to_2019 ~  plow + political_hierarchies + economic_complexity + fertility2019 + ln_income + ln_income_squared', data=df_cross_country_unpaid_mf).fit(cov_type='HC1')
funpaid = smf.ols(formula='f_unpaidwk2000_to_2019 ~  plow + political_hierarchies + economic_complexity + fertility2019 + ln_income + ln_income_squared', data=df_cross_country_unpaid_mf).fit(cov_type='HC1')
stargazer = Stargazer([funpaid, mfratio])
stargazer.custom_columns(['f_unpaidwk2000_to_2019', 'M/F ratio unpaidwk2000_to_2019'],[1,1])
stargazer
# Out:
# <table style="text-align:center"><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">f_unpaidwk2000_to_2019</td><td colspan="1">M/F ratio unpaidwk2000_to_2019</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td></tr><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">Intercept</td><td>-24.474<sup>*</sup></td><td>170.044<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td>(14.059)</td><td>(66.308)</td></tr><tr><td style="text-align:left">economic_complexity</td><td>-0.778<sup>***</sup></td><td>-0.309<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.267)</td><td>(0.946)</td></tr><tr><td style="text-align:left">fertility2019</td><td>0.309<sup></sup></td><td>-4.554<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.701)</td><td>(2.949)</td></tr><tr><td style="text-align:left">ln_income</td><td>10.813<sup>***</sup></td><td>-35.482<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td>(3.017)</td><td>(15.098)</td></tr><tr><td style="text-align:left">ln_income_squared</td><td>-0.650<sup>***</sup></td><td>2.485<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.174)</td><td>(0.900)</td></tr><tr><td style="text-align:left">plow</td><td>-1.208<sup></sup></td><td>-6.409<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(1.212)</td><td>(6.192)</td></tr><tr><td style="text-align:left">political_hierarchies</td><td>1.089<sup>*</sup></td><td>1.691<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.609)</td><td>(2.317)</td></tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>83</td><td>83</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.256</td><td>0.360</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.198</td><td>0.309</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>3.360 (df=76)</td><td>14.164 (df=76)</td></tr><tr><td style="text-align: left">F Statistic</td><td>4.780<sup>***</sup> (df=6; 76)</td><td>5.213<sup>***</sup> (df=6; 76)</td></tr><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="2" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# multicollinearity due to income and incomesquared, so not important for interpretting plow

# %%
# plot line graph
sns.set(rc={'figure.figsize':(10,5)})
sns.set_style('white')
ax = sns.regplot(x='plow', y='mfratio_unpaid2000_to_2019', data=df_cross_country_unpaid_mf, marker='o') # , color='#965786')
ax.set(title='plow vs (ratio of male vs female unpaid labour) (in %)')
# label points on the plot
for x, y, z in zip(df_cross_country_unpaid_mf['plow'], df_cross_country_unpaid_mf['mfratio_unpaid2000_to_2019'], df_cross_country_unpaid_mf['isocode']):
    # the position of the data label relative to the data point can be adjusted by adding/subtracting a value from the x &/ y coordinates
    plt.text(x = x, # x-coordinate position of data label
    y = y, # y-coordinate position of data label, adjusted to be 150 below the data point
    s = z) # data label, formatted to ignore decimals
    # color = 'purple') # set colour of line
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %% [markdown]
# #### With the selected countries in the above regression, what are the regression results for the original paper outcomes

# %%
res.fittedvalues.index
# Out:
# Int64Index([  2,   4,   8,   9,  12,  16,  18,  19,  24,  27,  28,  31,  33,
#              34,  39,  41,  42,  44,  47,  48,  58,  59,  60,  63,  65,  67,
#              72,  74,  76,  83,  86,  89,  91,  93,  95,  96,  98,  99, 101,
#             102, 106, 109, 116, 126, 129, 131, 134, 136, 138, 140, 141, 145,
#             146, 149, 152, 155, 157, 161, 162, 164, 165, 167, 172, 178, 179,
#             180, 181, 185, 186, 187, 189, 192, 200, 202, 210, 213, 214, 215,
#             217, 220, 223, 225, 230, 232],
#            dtype='int64')

# %%
df_cross_country_unpaid_mf2 = df_cross_country_unpaid_mf.iloc[res.fittedvalues.index]
df_cross_country_unpaid_mf2
# Out:
#     isocode  flfp2000  female_ownership  women_politics      plow  \
# 2       AGO      75.2              56.6            16.0  0.000000
# 4       ALB      50.2              10.8             5.0  1.000000
# 8       ARG      45.6              38.0            28.0  0.007799
# 9       ARM      57.2              31.8             3.0  0.977451
# 12      AUS      54.6               NaN            22.0  0.000000
# ..      ...       ...               ...             ...       ...
# 220     VEN      45.2              30.7            12.0  0.000000
# 223     VNM      69.5              59.2            26.0  0.872010
# 225     VUT      79.0              51.4             0.0  0.000000
# 230     ZAF      44.3              22.6            30.0  0.540551
# 232     ZMB      62.1              37.2            10.0  0.000000
#
#      agricultural_suitability  tropical_climate  large_animals  \
# 2                    0.921061          1.000000       0.998896
# 4                    0.555928          0.359318       1.000000
# 8                    0.546769          0.997066       0.797934
# 9                    0.594146          0.024724       1.000000
# 12                   0.419298          1.000000       0.000000
# ..                        ...               ...            ...
# 220                  0.158985          1.000000       0.548877
# 223                  0.156449          0.999991       1.000000
# 225                  0.000000          1.000000       1.000000
# 230                  0.865508          0.901535       0.999999
# 232                  0.955900          1.000000       0.754301
#
#      political_hierarchies  economic_complexity  ...  slope_temp  \
# 2                 2.720727             6.697217  ...  387.178406
# 4                 3.029723             5.035051  ...  347.221527
# 8                 2.256278             4.757950  ...  214.804932
# 9                 3.975265             6.856073  ...  197.239136
# 12                1.008231             1.000000  ...   58.831387
# ..                     ...                  ...  ...         ...
# 220               1.000000             3.069229  ...  286.166046
# 223               4.356279             6.651770  ...  444.235260
# 225               1.170613             7.000000  ...  514.373047
# 230               3.550035             5.920460  ...  430.698578
# 232               2.390349             5.871349  ...  247.966599
#
#      slope_precip  soil_temp  soil_precip  temp_precip       aes  \
# 2     1809.105957  20.141113    94.110115  1953.279907  3.473401
# 4     2491.556885   8.633903    61.954281   877.135620  1.537784
# 8     1043.644165  17.677864    85.889091  1942.565430  3.042557
# 9      974.693298   4.482770    22.152431   278.494995  1.994267
# 12     214.959457  17.444809    63.740234  1461.239746       NaN
# ..            ...        ...          ...          ...       ...
# 220   1364.811157  23.296183   111.106430  3193.269043  2.137608
# 223   3711.518311  15.295527   127.791817  4723.753418  3.871848
# 225   5305.303223  23.464685   242.017456  6088.801758  2.699995
# 230   1561.507446  15.252764    55.299240  1131.827759  2.816762
# 232   1030.538818  19.868818    82.573975  1837.584473  2.535204
#
#      f_unpaidwk2000_to_2019  fertility2019  m_unpaid2000_to_2019  \
# 2                       NaN          5.442                   NaN
# 4                  21.73611          1.414               3.47222
# 8                  23.41864          1.994               9.24860
# 9                  21.65833          1.575               4.37083
# 12                 20.83333          1.657              11.38889
# ..                      ...            ...                   ...
# 220                     NaN          2.250                   NaN
# 223                     NaN          1.948                   NaN
# 225                     NaN          3.813                   NaN
# 230                15.55556          2.475               6.45833
# 232                     NaN          4.451                   NaN
#
#      mfratio_unpaid2000_to_2019
# 2                           NaN
# 4                     15.974431
# 8                     39.492473
# 9                     20.180826
# 12                    54.666681
# ..                          ...
# 220                         NaN
# 223                         NaN
# 225                         NaN
# 230                   41.517824
# 232                         NaN
#
# [84 rows x 62 columns]

# %%
m_flfp_before = smf.ols(formula='flfp2000 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country).fit(cov_type='HC1')
m_flpf_after = smf.ols(formula='flfp2000 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + C(continent)', data=df_cross_country_unpaid_mf2).fit(cov_type='HC1')

m_fown_before = smf.ols(formula='female_ownership ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country).fit(cov_type='HC1')
m_fown_after = smf.ols(formula='female_ownership ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + C(continent)', data=df_cross_country_unpaid_mf2).fit(cov_type='HC1')

m_wpol_before = smf.ols(formula='women_politics ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country).fit(cov_type='HC1')
m_wpol_after = smf.ols(formula='women_politics ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + C(continent)', data=df_cross_country_unpaid_mf2).fit(cov_type='HC1')

m_aes_before = smf.ols(formula='aes ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country).fit(cov_type='HC1')
m_aes_after = smf.ols(formula='aes ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + C(continent)', data=df_cross_country_unpaid_mf2).fit(cov_type='HC1')
stargazer = Stargazer([m_flfp_before, m_flpf_after, m_fown_before, m_fown_after, m_wpol_before, m_wpol_after, m_aes_before, m_aes_after])
stargazer.custom_columns(['flfp2000 before', 'flfp2000 after', 'female_ownership before', 'female_ownership after', 'women_politics before', 'women_politics after', 'aes before', 'aes after'], [1, 1, 1, 1, 1, 1, 1, 1])
stargazer
# Out:
# <table style="text-align:center"><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">flfp2000 before</td><td colspan="1">flfp2000 after</td><td colspan="1">female_ownership before</td><td colspan="1">female_ownership after</td><td colspan="1">women_politics before</td><td colspan="1">women_politics after</td><td colspan="1">aes before</td><td colspan="1">aes after</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td></tr><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">C(continent)[T.Asia]</td><td></td><td>-6.508<sup></sup></td><td></td><td>4.266<sup></sup></td><td></td><td>1.372<sup></sup></td><td></td><td>0.556<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(6.956)</td><td></td><td>(8.630)</td><td></td><td>(3.292)</td><td></td><td>(0.325)</td></tr><tr><td style="text-align:left">C(continent)[T.Europe]</td><td></td><td>-20.280<sup>***</sup></td><td></td><td>3.608<sup></sup></td><td></td><td>3.798<sup></sup></td><td></td><td>0.605<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(7.195)</td><td></td><td>(12.865)</td><td></td><td>(5.501)</td><td></td><td>(0.399)</td></tr><tr><td style="text-align:left">C(continent)[T.North America]</td><td></td><td>-19.676<sup>***</sup></td><td></td><td>0.516<sup></sup></td><td></td><td>5.291<sup></sup></td><td></td><td>-0.189<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(4.268)</td><td></td><td>(6.517)</td><td></td><td>(3.938)</td><td></td><td>(0.187)</td></tr><tr><td style="text-align:left">C(continent)[T.Oceania]</td><td></td><td>-6.242<sup></sup></td><td></td><td>9.310<sup></sup></td><td></td><td>0.161<sup></sup></td><td></td><td>0.056<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(8.977)</td><td></td><td>(8.426)</td><td></td><td>(3.687)</td><td></td><td>(0.318)</td></tr><tr><td style="text-align:left">C(continent)[T.South America]</td><td></td><td>-14.037<sup>**</sup></td><td></td><td>7.816<sup></sup></td><td></td><td>2.624<sup></sup></td><td></td><td>-0.089<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(5.747)</td><td></td><td>(7.278)</td><td></td><td>(4.483)</td><td></td><td>(0.285)</td></tr><tr><td style="text-align:left">Intercept</td><td>51.658<sup>***</sup></td><td>61.393<sup>***</sup></td><td>34.481<sup>***</sup></td><td>34.940<sup>**</sup></td><td>17.096<sup>***</sup></td><td>7.681<sup></sup></td><td>2.020<sup>***</sup></td><td>1.941<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(6.338)</td><td>(10.031)</td><td>(10.386)</td><td>(16.193)</td><td>(4.810)</td><td>(7.105)</td><td>(0.302)</td><td>(0.594)</td></tr><tr><td style="text-align:left">agricultural_suitability</td><td>9.407<sup>**</sup></td><td>10.534<sup>*</sup></td><td>1.514<sup></sup></td><td>-1.403<sup></sup></td><td>1.009<sup></sup></td><td>2.210<sup></sup></td><td>0.312<sup></sup></td><td>0.267<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(3.885)</td><td>(5.922)</td><td>(5.358)</td><td>(8.819)</td><td>(2.799)</td><td>(4.533)</td><td>(0.229)</td><td>(0.316)</td></tr><tr><td style="text-align:left">economic_complexity</td><td>0.170<sup></sup></td><td>2.199<sup>*</sup></td><td>1.810<sup>*</sup></td><td>1.948<sup></sup></td><td>1.082<sup>**</sup></td><td>-0.014<sup></sup></td><td>0.048<sup></sup></td><td>-0.012<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.849)</td><td>(1.274)</td><td>(1.023)</td><td>(1.619)</td><td>(0.491)</td><td>(0.718)</td><td>(0.037)</td><td>(0.059)</td></tr><tr><td style="text-align:left">large_animals</td><td>10.903<sup>**</sup></td><td>-1.011<sup></sup></td><td>-0.649<sup></sup></td><td>11.147<sup></sup></td><td>-9.152<sup>**</sup></td><td>-4.718<sup></sup></td><td>0.174<sup></sup></td><td>0.240<sup></sup></td></tr ...
#  <td colspan="8" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# # Extension: Regression Models

# %% [markdown]
# ## Replication of the paper

# %% [markdown]
# ### Table 3

# %%
m_flfp = smf.ols(formula='flfp2000 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country).fit(cov_type='HC1')
m_flpf_c = smf.ols(formula='flfp2000 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + C(continent)', data=df_cross_country).fit(cov_type='HC1')

m_fown = smf.ols(formula='female_ownership ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country).fit(cov_type='HC1')
m_fown_c = smf.ols(formula='female_ownership ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + C(continent)', data=df_cross_country).fit(cov_type='HC1')

m_wpol = smf.ols(formula='women_politics ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country).fit(cov_type='HC1')
m_wpol_c = smf.ols(formula='women_politics ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + C(continent)', data=df_cross_country).fit(cov_type='HC1')

m_aes = smf.ols(formula='aes ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country).fit(cov_type='HC1')
m_aes_c = smf.ols(formula='aes ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + C(continent)', data=df_cross_country).fit(cov_type='HC1')
Stargazer([m_flfp, m_flpf_c, m_fown, m_fown_c, m_wpol, m_wpol_c, m_aes, m_aes_c])
# Out:
# <table style="text-align:center"><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td></tr><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">C(continent)[T.Africa]</td><td></td><td>14.193<sup>***</sup></td><td></td><td>-3.620<sup></sup></td><td></td><td>1.474<sup></sup></td><td></td><td>0.109<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(3.196)</td><td></td><td>(3.370)</td><td></td><td>(1.547)</td><td></td><td>(0.123)</td></tr><tr><td style="text-align:left">C(continent)[T.Asia]</td><td></td><td>10.178<sup>***</sup></td><td></td><td>3.652<sup></sup></td><td></td><td>0.321<sup></sup></td><td></td><td>0.310<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(3.314)</td><td></td><td>(3.699)</td><td></td><td>(1.781)</td><td></td><td>(0.156)</td></tr><tr><td style="text-align:left">C(continent)[T.Europe]</td><td></td><td>4.534<sup></sup></td><td></td><td>10.488<sup>*</sup></td><td></td><td>5.795<sup>**</sup></td><td></td><td>0.723<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(4.011)</td><td></td><td>(5.986)</td><td></td><td>(2.476)</td><td></td><td>(0.189)</td></tr><tr><td style="text-align:left">C(continent)[T.North America]</td><td></td><td>1.124<sup></sup></td><td></td><td>4.392<sup></sup></td><td></td><td>3.143<sup>*</sup></td><td></td><td>0.064<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(2.815)</td><td></td><td>(3.728)</td><td></td><td>(1.708)</td><td></td><td>(0.142)</td></tr><tr><td style="text-align:left">C(continent)[T.Oceania]</td><td></td><td>10.108<sup>*</sup></td><td></td><td>13.686<sup>***</sup></td><td></td><td>1.454<sup></sup></td><td></td><td>0.281<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(5.967)</td><td></td><td>(5.112)</td><td></td><td>(3.321)</td><td></td><td>(0.234)</td></tr><tr><td style="text-align:left">C(continent)[T.South America]</td><td></td><td>4.257<sup></sup></td><td></td><td>2.959<sup></sup></td><td></td><td>2.873<sup></sup></td><td></td><td>0.217<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(2.810)</td><td></td><td>(3.588)</td><td></td><td>(2.242)</td><td></td><td>(0.146)</td></tr><tr><td style="text-align:left">Intercept</td><td>51.658<sup>***</sup></td><td>44.394<sup>***</sup></td><td>34.481<sup>***</sup></td><td>31.556<sup>***</sup></td><td>17.096<sup>***</sup></td><td>15.060<sup>***</sup></td><td>2.020<sup>***</sup></td><td>1.704<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(6.338)</td><td>(5.682)</td><td>(10.386)</td><td>(9.726)</td><td>(4.810)</td><td>(3.953)</td><td>(0.302)</td><td>(0.306)</td></tr><tr><td style="text-align:left">agricultural_suitability</td><td>9.407<sup>**</sup></td><td>9.017<sup>**</sup></td><td>1.514<sup></sup></td><td>4.619<sup></sup></td><td>1.009<sup></sup></td><td>-0.687<sup></sup></td><td>0.312<sup></sup></td><td>0.325<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(3.885)</td><td>(4.236)</td><td>(5.358)</td><td>(5.836)</td><td>(2.799)</td><td>(2.925)</td><td>(0.229)</td><td>(0.240)</td></tr><tr><td style="text-align:left">economic_complexity</td><td>0.170<sup></sup></td><td>1.157<sup></sup></td><td>1.810<sup>*</sup></td><td>0.517<sup></sup></td><td>1.082<sup>**</sup></td><td>0.727<sup></sup></td><td>0.048<sup></sup></td><td>0.018<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.849)</td><td>(0.859)</td><td>(1.023)</td><td>(1.351)</td><td>(0.491)</td><td>(0.510)</td><td>(0.037)</td><td>(0.047)</td></tr><tr><td style="text-align:left">large_animals</td><td>10.903<sup>**</sup></td><td>2.350<sup></sup></td><td>-0.649<sup></sup></td><td>4.475<sup></sup></td><td>-9.152<sup>**</sup></td><td>-7.338<sup></sup></td><td>0.174<sup></sup></td><td> ...
#  <td colspan="8" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# #### Correlation Matrix

# %%
t3_cols = ['plow','agricultural_suitability', 'tropical_climate', 'large_animals','political_hierarchies', 'economic_complexity']
corr_matrix = np.corrcoef(df_cross_country[t3_cols].dropna().T)
sm.graphics.plot_corr(corr_matrix, xnames=df_cross_country[t3_cols].columns)
plt.title('Correlation Matrix for Table 3')
plt.show()

# %% [markdown]
# ### Table 4

# %%
m_flfp = smf.ols(formula='flfp2000 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared', data=df_cross_country).fit(cov_type='HC1')
m_fown = smf.ols(formula='female_ownership ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared', data=df_cross_country).fit(cov_type='HC1')
m_wpol = smf.ols(formula='women_politics ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared', data=df_cross_country).fit(cov_type='HC1')
m_aes = smf.ols(formula='aes ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared', data=df_cross_country).fit(cov_type='HC1')

m_flfp_c = smf.ols(formula='flfp2000 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared + C(continent)', data=df_cross_country).fit(cov_type='HC1')
m_fown_c = smf.ols(formula='female_ownership ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared + C(continent)', data=df_cross_country).fit(cov_type='HC1')
m_wpol_c = smf.ols(formula='women_politics ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared + C(continent)', data=df_cross_country).fit(cov_type='HC1')
m_aes_c = smf.ols(formula='aes ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared + C(continent)', data=df_cross_country).fit(cov_type='HC1')
Stargazer([m_flfp, m_flfp_c, m_fown, m_fown_c, m_wpol, m_wpol_c, m_aes, m_aes_c])
# Out:
# <table style="text-align:center"><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td></tr><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">C(continent)[T.Africa]</td><td></td><td>27.488<sup>***</sup></td><td></td><td>-7.596<sup></sup></td><td></td><td>4.630<sup>**</sup></td><td></td><td>0.452<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(4.429)</td><td></td><td>(6.398)</td><td></td><td>(2.239)</td><td></td><td>(0.223)</td></tr><tr><td style="text-align:left">C(continent)[T.Asia]</td><td></td><td>26.675<sup>***</sup></td><td></td><td>1.056<sup></sup></td><td></td><td>3.593<sup></sup></td><td></td><td>0.665<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(4.931)</td><td></td><td>(5.815)</td><td></td><td>(2.790)</td><td></td><td>(0.257)</td></tr><tr><td style="text-align:left">C(continent)[T.Europe]</td><td></td><td>23.813<sup>***</sup></td><td></td><td>8.511<sup></sup></td><td></td><td>8.459<sup>**</sup></td><td></td><td>1.108<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(5.643)</td><td></td><td>(7.011)</td><td></td><td>(3.456)</td><td></td><td>(0.285)</td></tr><tr><td style="text-align:left">C(continent)[T.North America]</td><td></td><td>22.532<sup>***</sup></td><td></td><td>2.607<sup></sup></td><td></td><td>3.627<sup></sup></td><td></td><td>0.592<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(5.187)</td><td></td><td>(7.776)</td><td></td><td>(3.041)</td><td></td><td>(0.301)</td></tr><tr><td style="text-align:left">C(continent)[T.Oceania]</td><td></td><td>30.814<sup>***</sup></td><td></td><td>9.454<sup></sup></td><td></td><td>3.360<sup></sup></td><td></td><td>0.862<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(7.136)</td><td></td><td>(9.269)</td><td></td><td>(3.435)</td><td></td><td>(0.366)</td></tr><tr><td style="text-align:left">C(continent)[T.South America]</td><td></td><td>25.854<sup>***</sup></td><td></td><td>0.531<sup></sup></td><td></td><td>6.109<sup>*</sup></td><td></td><td>0.745<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(5.205)</td><td></td><td>(7.217)</td><td></td><td>(3.217)</td><td></td><td>(0.279)</td></tr><tr><td style="text-align:left">Intercept</td><td>193.755<sup>***</sup></td><td>157.175<sup>***</sup></td><td>-6.468<sup></sup></td><td>14.563<sup></sup></td><td>34.679<sup>**</sup></td><td>29.778<sup>**</sup></td><td>4.911<sup>***</sup></td><td>4.424<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(26.417)</td><td>(24.609)</td><td>(37.991)</td><td>(35.019)</td><td>(15.359)</td><td>(14.326)</td><td>(1.483)</td><td>(1.422)</td></tr><tr><td style="text-align:left">agricultural_suitability</td><td>6.073<sup></sup></td><td>7.181<sup>*</sup></td><td>0.803<sup></sup></td><td>4.322<sup></sup></td><td>2.198<sup></sup></td><td>1.081<sup></sup></td><td>0.262<sup></sup></td><td>0.342<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(3.696)</td><td>(4.175)</td><td>(5.447)</td><td>(6.071)</td><td>(2.605)</td><td>(2.548)</td><td>(0.249)</td><td>(0.254)</td></tr><tr><td style="text-align:left">economic_complexity</td><td>1.157<sup></sup></td><td>1.411<sup>*</sup></td><td>1.693<sup></sup></td><td>0.764<sup></sup></td><td>0.454<sup></sup></td><td>0.333<sup></sup></td><td>0.063<sup></sup></td><td>0.027<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.793)</td><td>(0.815)</td><td>(1.129)</td><td>(1.382)</td><td>(0.487)</td><td>(0.502)</td><td>(0.041)</td><td>(0.047)</td></tr><tr><td style="text-align:left">large_animals</td><td>-2.015<sup></sup></td><td>-2.166<sup></sup></td><td>2.707<sup></sup></td><td>5.610<sup></sup></td><td>-5.718<sup></sup></td><td>-4.688<sup></sup></td><td>0.005<sup></sup> ...
#  <td colspan="8" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# #### Correlation Matrix

# %%
t4_cols = ['plow','agricultural_suitability', 'tropical_climate', 'large_animals','political_hierarchies', 'economic_complexity','ln_income', 'ln_income_squared']
corr_matrix = np.corrcoef(df_cross_country[t4_cols].dropna().T)
sm.graphics.plot_corr(corr_matrix, xnames=df_cross_country[t4_cols].columns)
plt.title('Correlation Matrix for Table 4')
plt.show()

# %% [markdown]
# ## Extension 1. Table 3 and 4 in 2019

# %% [markdown]
# ### Table 3

# %%
m_fl19 = smf.ols(formula='flfp2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country2019).fit(cov_type='HC1')
m_wp19 = smf.ols(formula='women_politics2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country2019).fit(cov_type='HC1')
m_fo19 = smf.ols(formula='female_ownership2010_to_2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country2019).fit(cov_type='HC1')
m_aes19 = smf.ols(formula='aes2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity', data=df_cross_country2019).fit(cov_type='HC1')

m_fl19_c = smf.ols(formula='flfp2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity+ C(continent)', data=df_cross_country2019).fit(cov_type='HC1')
m_wp19_c = smf.ols(formula='women_politics2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity+ C(continent)', data=df_cross_country2019).fit(cov_type='HC1')
m_fo19_c = smf.ols(formula='female_ownership2010_to_2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity+ C(continent)', data=df_cross_country2019).fit(cov_type='HC1')
m_aes19_c = smf.ols(formula='aes2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity+ C(continent)', data=df_cross_country2019).fit(cov_type='HC1')
Stargazer([m_fl19,m_fl19_c, m_fo19, m_fo19_c, m_wp19, m_wp19_c, m_aes19, m_aes19_c])
# Out:
# <table style="text-align:center"><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td></tr><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">C(continent)[T.Africa]</td><td></td><td>5.911<sup>*</sup></td><td></td><td>-7.083<sup>**</sup></td><td></td><td>3.681<sup></sup></td><td></td><td>0.032<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(3.217)</td><td></td><td>(3.605)</td><td></td><td>(2.409)</td><td></td><td>(0.159)</td></tr><tr><td style="text-align:left">C(continent)[T.Asia]</td><td></td><td>5.652<sup></sup></td><td></td><td>-0.083<sup></sup></td><td></td><td>0.301<sup></sup></td><td></td><td>0.211<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(3.574)</td><td></td><td>(3.941)</td><td></td><td>(2.458)</td><td></td><td>(0.169)</td></tr><tr><td style="text-align:left">C(continent)[T.Europe]</td><td></td><td>12.025<sup>***</sup></td><td></td><td>-0.450<sup></sup></td><td></td><td>12.441<sup>***</sup></td><td></td><td>0.700<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(3.901)</td><td></td><td>(5.486)</td><td></td><td>(3.049)</td><td></td><td>(0.206)</td></tr><tr><td style="text-align:left">C(continent)[T.North America]</td><td></td><td>4.187<sup></sup></td><td></td><td>-0.482<sup></sup></td><td></td><td>7.451<sup>**</sup></td><td></td><td>0.151<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(3.097)</td><td></td><td>(3.888)</td><td></td><td>(3.330)</td><td></td><td>(0.172)</td></tr><tr><td style="text-align:left">C(continent)[T.Oceania]</td><td></td><td>12.579<sup>**</sup></td><td></td><td>16.227<sup>***</sup></td><td></td><td>-2.743<sup></sup></td><td></td><td>0.237<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(5.584)</td><td></td><td>(5.124)</td><td></td><td>(4.366)</td><td></td><td>(0.367)</td></tr><tr><td style="text-align:left">C(continent)[T.South America]</td><td></td><td>8.587<sup>***</sup></td><td></td><td>16.090<sup>***</sup></td><td></td><td>7.778<sup>**</sup></td><td></td><td>0.730<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(2.997)</td><td></td><td>(4.154)</td><td></td><td>(3.401)</td><td></td><td>(0.173)</td></tr><tr><td style="text-align:left">Intercept</td><td>60.999<sup>***</sup></td><td>48.941<sup>***</sup></td><td>40.582<sup>***</sup></td><td>24.220<sup>**</sup></td><td>33.303<sup>***</sup></td><td>28.910<sup>***</sup></td><td>2.866<sup>***</sup></td><td>2.060<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(8.404)</td><td>(7.184)</td><td>(11.943)</td><td>(9.600)</td><td>(5.253)</td><td>(5.323)</td><td>(0.364)</td><td>(0.328)</td></tr><tr><td style="text-align:left">agricultural_suitability</td><td>8.563<sup>**</sup></td><td>8.205<sup>*</sup></td><td>-2.371<sup></sup></td><td>6.277<sup></sup></td><td>4.901<sup></sup></td><td>0.717<sup></sup></td><td>0.245<sup></sup></td><td>0.346<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(4.052)</td><td>(4.641)</td><td>(5.407)</td><td>(5.584)</td><td>(3.469)</td><td>(3.595)</td><td>(0.246)</td><td>(0.270)</td></tr><tr><td style="text-align:left">economic_complexity</td><td>2.562<sup>***</sup></td><td>2.376<sup>**</sup></td><td>2.357<sup>**</sup></td><td>1.521<sup></sup></td><td>-0.567<sup></sup></td><td>-1.138<sup>**</sup></td><td>0.060<sup></sup></td><td>0.018<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.908)</td><td>(0.969)</td><td>(0.958)</td><td>(1.054)</td><td>(0.483)</td><td>(0.450)</td><td>(0.042)</td><td>(0.048)</td></tr><tr><td style="text-align:left">large_animals</td><td>-2.777<sup></sup></td><td>0.555<sup></sup></td><td>-21.318<sup>*</sup></td><td>-3.235<sup></sup></td><td>-12.940<sup>***</sup></td><td>-9.076<sup></sup></td><td>- ...
#  <td colspan="8" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# ### Table 4

# %%
m_fl19 = smf.ols(formula='flfp2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity+ ln_income + ln_income_squared', data=df_cross_country2019).fit(cov_type='HC1')
m_wp19 = smf.ols(formula='women_politics2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared', data=df_cross_country2019).fit(cov_type='HC1')
m_fo19 = smf.ols(formula='female_ownership2010_to_2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared', data=df_cross_country2019).fit(cov_type='HC1')
m_aes19 = smf.ols(formula='aes2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared', data=df_cross_country2019).fit(cov_type='HC1')

m_fl19_c = smf.ols(formula='flfp2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared + C(continent)', data=df_cross_country2019).fit(cov_type='HC1')
m_wp19_c = smf.ols(formula='women_politics2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared+ C(continent)', data=df_cross_country2019).fit(cov_type='HC1')
m_fo19_c = smf.ols(formula='female_ownership2010_to_2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared+ C(continent)', data=df_cross_country2019).fit(cov_type='HC1')
m_aes19_c = smf.ols(formula='aes2019 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + ln_income + ln_income_squared+ C(continent)', data=df_cross_country2019).fit(cov_type='HC1')
Stargazer([m_fl19, m_fl19_c, m_fo19, m_fo19_c, m_wp19, m_wp19_c, m_aes19, m_aes19_c])
# Out:
# <table style="text-align:center"><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td></tr><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">C(continent)[T.Africa]</td><td></td><td>22.710<sup>***</sup></td><td></td><td>-5.853<sup></sup></td><td></td><td>10.987<sup>***</sup></td><td></td><td>0.780<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(4.274)</td><td></td><td>(7.014)</td><td></td><td>(3.415)</td><td></td><td>(0.313)</td></tr><tr><td style="text-align:left">C(continent)[T.Asia]</td><td></td><td>24.183<sup>***</sup></td><td></td><td>-2.986<sup></sup></td><td></td><td>6.491<sup>*</sup></td><td></td><td>0.826<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(5.452)</td><td></td><td>(5.573)</td><td></td><td>(3.616)</td><td></td><td>(0.296)</td></tr><tr><td style="text-align:left">C(continent)[T.Europe]</td><td></td><td>31.317<sup>***</sup></td><td></td><td>-5.709<sup></sup></td><td></td><td>18.446<sup>***</sup></td><td></td><td>1.165<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(6.004)</td><td></td><td>(7.313)</td><td></td><td>(4.271)</td><td></td><td>(0.340)</td></tr><tr><td style="text-align:left">C(continent)[T.North America]</td><td></td><td>23.878<sup>***</sup></td><td></td><td>-3.544<sup></sup></td><td></td><td>13.310<sup>***</sup></td><td></td><td>0.916<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(5.885)</td><td></td><td>(9.193)</td><td></td><td>(4.705)</td><td></td><td>(0.415)</td></tr><tr><td style="text-align:left">C(continent)[T.Oceania]</td><td></td><td>31.560<sup>***</sup></td><td></td><td>14.555<sup></sup></td><td></td><td>4.093<sup></sup></td><td></td><td>1.118<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(6.497)</td><td></td><td>(10.034)</td><td></td><td>(5.014)</td><td></td><td>(0.525)</td></tr><tr><td style="text-align:left">C(continent)[T.South America]</td><td></td><td>30.472<sup>***</sup></td><td></td><td>11.882<sup></sup></td><td></td><td>15.440<sup>***</sup></td><td></td><td>1.442<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(5.628)</td><td></td><td>(8.762)</td><td></td><td>(4.789)</td><td></td><td>(0.394)</td></tr><tr><td style="text-align:left">Intercept</td><td>183.486<sup>***</sup></td><td>164.120<sup>***</sup></td><td>-8.082<sup></sup></td><td>8.344<sup></sup></td><td>70.835<sup>***</sup></td><td>68.767<sup>***</sup></td><td>6.930<sup>***</sup></td><td>6.247<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(27.149)</td><td>(26.746)</td><td>(41.648)</td><td>(40.439)</td><td>(22.660)</td><td>(18.883)</td><td>(1.907)</td><td>(1.888)</td></tr><tr><td style="text-align:left">agricultural_suitability</td><td>5.988<sup></sup></td><td>6.357<sup></sup></td><td>-4.810<sup></sup></td><td>1.827<sup></sup></td><td>3.098<sup></sup></td><td>-1.327<sup></sup></td><td>0.013<sup></sup></td><td>0.123<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(4.096)</td><td>(4.629)</td><td>(5.261)</td><td>(5.538)</td><td>(3.420)</td><td>(3.477)</td><td>(0.257)</td><td>(0.287)</td></tr><tr><td style="text-align:left">economic_complexity</td><td>2.168<sup>**</sup></td><td>1.859<sup>*</sup></td><td>1.500<sup></sup></td><td>1.483<sup></sup></td><td>-0.772<sup></sup></td><td>-1.200<sup>**</sup></td><td>0.046<sup></sup></td><td>0.026<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.946)</td><td>(0.969)</td><td>(1.085)</td><td>(1.074)</td><td>(0.540)</td><td>(0.508)</td><td>(0.046)</td><td>(0.049)</td></tr><tr><td style="text-align:left">large_animals</td><td>-5.569<sup></sup></td><td>-0.223<sup></sup></td><td>-14.549<sup></sup></td><td>-4.476<sup></sup></td><td>-11.680<sup>**</sup></td><td>-9.625<sup ...
#  <td colspan="8" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# ## Extension 2. New outcome variable. Plow vs female unpaid labour.

# %%
mod = smf.ols(formula='f_unpaidwk2000_to_2019 ~  plow + political_hierarchies + economic_complexity + fertility2019 + ln_income + ln_income_squared', data=df_cross_country_unpaid)
res = mod.fit(cov_type='HC1')
print(res.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     f_unpaidwk2000_to_2019   R-squared:                       0.256
# Model:                                OLS   Adj. R-squared:                  0.198
# Method:                     Least Squares   F-statistic:                     4.780
# Date:                    Thu, 02 Feb 2023   Prob (F-statistic):           0.000349
# Time:                            19:16:32   Log-Likelihood:                -214.71
# No. Observations:                      83   AIC:                             443.4
# Df Residuals:                          76   BIC:                             460.4
# Df Model:                               6
# Covariance Type:                      HC1
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept               -24.4737     14.059     -1.741      0.082     -52.030       3.082
# plow                     -1.2076      1.212     -0.997      0.319      -3.583       1.167
# political_hierarchies     1.0894      0.609      1.790      0.073      -0.103       2.282
# economic_complexity      -0.7781      0.267     -2.911      0.004      -1.302      -0.254
# fertility2019             0.3094      0.701      0.441      0.659      -1.064       1.683
# ln_income                10.8126      3.017      3.584      0.000       4.899      16.726
# ln_income_squared        -0.6496      0.174     -3.741      0.000      -0.990      -0.309
# ==============================================================================
# Omnibus:                       16.007   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.718
# Skew:                          -0.542   Prob(JB):                     1.44e-09
# Kurtosis:                       6.255   Cond. No.                     2.67e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The condition number is large, 2.67e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
mod = smf.ols(formula='f_unpaidwk2000_to_2019 ~  plow + political_hierarchies + economic_complexity + fertility2019 + ln_income + ln_income_squared', data=df_cross_country_unpaid).fit(cov_type='HC1')
Stargazer([mod])
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable:f_unpaidwk2000_to_2019</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">Intercept</td><td>-24.474<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td>(14.059)</td></tr><tr><td style="text-align:left">economic_complexity</td><td>-0.778<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.267)</td></tr><tr><td style="text-align:left">fertility2019</td><td>0.309<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.701)</td></tr><tr><td style="text-align:left">ln_income</td><td>10.813<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(3.017)</td></tr><tr><td style="text-align:left">ln_income_squared</td><td>-0.650<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.174)</td></tr><tr><td style="text-align:left">plow</td><td>-1.208<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(1.212)</td></tr><tr><td style="text-align:left">political_hierarchies</td><td>1.089<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td>(0.609)</td></tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>83</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.256</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.198</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>3.360 (df=76)</td></tr><tr><td style="text-align: left">F Statistic</td><td>4.780<sup>***</sup> (df=6; 76)</td></tr><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="1" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# ## Extension 3. Additional Ethnographic Atlas controls

# %%
best
# Out:
# ['EA034', 'EA064', 'EA050']

# %%
[var_dict[best[i]] for i in range(len(best))]
# Out:
# ['Religion: high gods',
#  'Age or occupational specialization: animal husbandry',
#  'Sex differences: gathering']

# %%
m1 = smf.ols(formula='flfp2000 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + C(EA034)', data=df_cross_country_ea).fit(cov_type='HC1')
m2 = smf.ols(formula='flfp2000 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + C(EA034) + C(EA064)', data=df_cross_country_ea).fit(cov_type='HC1')
m3 = smf.ols(formula='flfp2000 ~  plow + agricultural_suitability + tropical_climate + large_animals + political_hierarchies + economic_complexity + C(EA034) + C(EA064) + C(EA050)', data=df_cross_country_ea).fit(cov_type='HC1')
Stargazer([m1, m2, m3])
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/ada/lib/python3.10/site-packages/statsmodels/base/model.py:1871: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 21, but rank is 20
#   warnings.warn('covariance of constraints does not have full '
# <table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable:flfp2000</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">C(EA034)[T.Active, but not supporting morality]</td><td>-7.198<sup></sup></td><td>-6.031<sup></sup></td><td>1.602<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(7.475)</td><td>(8.794)</td><td>(8.186)</td></tr><tr><td style="text-align:left">C(EA034)[T.Active, supporting morality]</td><td>-16.256<sup>***</sup></td><td>-18.250<sup>***</sup></td><td>-18.530<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(3.712)</td><td>(3.691)</td><td>(3.770)</td></tr><tr><td style="text-align:left">C(EA034)[T.Missing data]</td><td>-1.657<sup></sup></td><td>-1.140<sup></sup></td><td>-2.013<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(3.940)</td><td>(3.784)</td><td>(3.806)</td></tr><tr><td style="text-align:left">C(EA034)[T.Otiose]</td><td>3.312<sup></sup></td><td>2.842<sup></sup></td><td>5.130<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(5.094)</td><td>(4.742)</td><td>(4.529)</td></tr><tr><td style="text-align:left">C(EA050)[T.Activity present, sex diff. unspecified]</td><td></td><td></td><td>31.199<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td></td><td>(4.806)</td></tr><tr><td style="text-align:left">C(EA050)[T.Both, females more]</td><td></td><td></td><td>-14.481<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td></td><td>(5.234)</td></tr><tr><td style="text-align:left">C(EA050)[T.Both, males more]</td><td></td><td></td><td>2.248<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td></td><td>(6.609)</td></tr><tr><td style="text-align:left">C(EA050)[T.Differentiated but equal]</td><td></td><td></td><td>8.225<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td></td><td>(7.872)</td></tr><tr><td style="text-align:left">C(EA050)[T.Equal participation]</td><td></td><td></td><td>6.895<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td></td><td>(8.567)</td></tr><tr><td style="text-align:left">C(EA050)[T.Females alone]</td><td></td><td></td><td>3.972<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td></td><td>(4.283)</td></tr><tr><td style="text-align:left">C(EA050)[T.Males alone]</td><td></td><td></td><td>-0.000<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td></td><td>(0.000)</td></tr><tr><td style="text-align:left">C(EA050)[T.Missing data]</td><td></td><td></td><td>6.516<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td></td><td>(3.787)</td></tr><tr><td style="text-align:left">C(EA064)[T.Craft]</td><td></td><td>25.623<sup>***</sup></td><td>30.165<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(5.823)</td><td>(6.291)</td></tr><tr><td style="text-align:left">C(EA064)[T.Missing data]</td><td></td><td>5.552<sup></sup></td><td>4.524<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(4.108)</td><td>(3.913)</td></tr><tr><td style="text-align:left">C(EA064)[T.Most adults]</td><td></td><td>11.649<sup>***</sup></td><td>12.227<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(4.074)</td><td>(3.758)</td></tr><tr><td style="text-align:left">Intercept</td><td>53.922<sup>***</sup></td><td>54.826<sup>***</sup></td><td>53.533<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(7.928)</td><td>(7.734)</td><td>(8.600)</td></tr><tr><td style="text-align:left">agricultural_suitability</td><td>11.687<sup>***</sup></td><td>10.227<sup>**</sup></td><td>7.734<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td>(4.447)</td><td>(4.298)</td><td>(4.568)</t ...
#  <td colspan="3" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# ## Plots

# %% [markdown]
# Results weak. Explanation: self selection problem with countries in time spent at home being high plow and high development.

# %%
# plot line graph
sns.set(rc={'figure.figsize':(10,5)})
sns.set_style('white')
ax = sns.regplot(x='plow', y='f_unpaidwk2000_to_2019', data=df_cross_country_unpaid, marker='o') # , color='#965786')
ax.set(title='plow vs female unpaid work (% of day)')
# label points on the plot
for x, y, z in zip(df_cross_country_unpaid['plow'], df_cross_country_unpaid['f_unpaidwk2000_to_2019'], df_cross_country_unpaid['isocode']):
    # the position of the data label relative to the data point can be adjusted by adding/subtracting a value from the x &/ y coordinates
    plt.text(x = x, # x-coordinate position of data label
    y = y, # y-coordinate position of data label, adjusted to be 150 below the data point
    s = z) # data label, formatted to ignore decimals
    # color = 'purple') # set colour of line
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
# plot line graph
sns.set(rc={'figure.figsize':(10,5)})
sns.set_style('white')
ax = sns.regplot(x='plow', y='flfp2000', data=df_cross_country_unpaid, marker='o') # , color='#965786')
ax.set(title='plow vs female labour force participation in 2000')
# label points on the plot
for x, y, z in zip(df_cross_country_unpaid['plow'], df_cross_country_unpaid['flfp2000'], df_cross_country_unpaid['isocode']):
    # the position of the data label relative to the data point can be adjusted by adding/subtracting a value from the x &/ y coordinates
    plt.text(x = x, # x-coordinate position of data label
    y = y, # y-coordinate position of data label, adjusted to be 150 below the data point
    s = z) # data label, formatted to ignore decimals
    # color = 'purple') # set colour of line
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
